# %%
from pathlib import Path
import tensorflow.keras as keras
import tensorflow as tf
import sys
import json
import os
import music21 as m21
import numpy as np
from typing import List
import matplotlib.pyplot as plt

# %%
class FileHelper:
    def __init__(self):
        pass

    def load_file_as_str(self, file_path: str) -> str:
        """
        Loads the file at a specificed path, returns an error otherwise
        
        :param file_path (str): The path to the file you want to load
        :return _file a str of the contents of the file
        """
        _file = ""
        try:
            with open(file_path, "r") as fp:
                _file = fp.read()
            return _file
        except Exception:
            raise Exception(f"Error reading file at: {file_path}")

    # TODO: Might not need this
    def readBytes(self, file_path) -> bytes:
        try:
            with open(file_path, "rb") as fb:
                file_bytes = fb.read()
                return file_bytes
        except Exception:
            raise Exception(f"Error trying to read bytes at: {file_path}")
            
    def loadJSON(self, file_path) -> dict:
        try:
            with open(file_path) as json_data:
                data = json.load(json_data)
            return data
        except Exception:
            raise Exception(f"Could not open file located at: {file_path}")

# %%
# durations are expressed in quarter length
ACCEPTABLE_DURATIONS = [
    0.25, # 16th note
    0.5, # 8th note
    0.75,
    1.0, # quarter note
    1.5,
    2, # half note
    3,
    4 # whole note
]

class MusicHelper:
    def __init__(self, file_helper: FileHelper, acceptable_durations=ACCEPTABLE_DURATIONS):
        """
        :param file_helper (FileHelper): This is a file_helper object to help with writing/reading files
        :param acceptable_durations (List[float]): This is the range of notes that are ok to add for the model
        :return MusicHelper: This is the constructor for the class
        """
        print("MusicHelper has been created...")
        self.acceptable_durations = acceptable_durations
        self._file_helper = file_helper

    def load_songs(self, dataset_path: str, file_type: str):
        """
        Loads all pieces of a specific file type

        :param dataset_path (str): Path to dataset
        :param file_stype (str): The file type you want to load
        :return songs (list of m21 streams): List containing all pieces
        """
        print("Loading songs....")
        songs = []
        len_file_ext = len(file_type)

        # go through all the files in dataset and load them with music21
        for path, _, files in os.walk(dataset_path):
            for file in files:

                # consider only files of the target type
                if file[-len_file_ext:] == file_type:
                    try:
                        song = m21.converter.parse(os.path.join(path, file))
                        if self.monophonic(song):
                            songs.append(song)
                    except Exception:
                        print(f"Error processing file located at: {os.path.join(path, file)}")
        return songs
    
    def monophonic(self, stream) -> bool:
        try:
            length = len(m21.instrument.partitionByInstrument(stream).parts)
        except:
            length = 0
        return length == 1

    def transpose_song(self, song, major_key: str, minor_key: str):
        """
        Transposes song to a specified major/minor key.
        If the song is in a major scale it is transposed to the specified key, vice versa

        Defaults are in place in case the programmer forgets them

        :param song (m21 stream): The song to transpose
        :param major_key (str): The musical major key you want to transpose to
        :param minor_key (str): The musical minor key you want to transpose to
        :return transposed_song (m21 stream):
        """
        #print("Transposing song....")
        # get key from the song
        parts = song.getElementsByClass(m21.stream.Part)
        measures_part0 = parts[0].getElementsByClass(m21.stream.Measure)
        key = song.analyze("key")

        # get interval for transposition. E.g., Bmaj -> Cmaj
        if key.mode == "major":
            interval = m21.interval.Interval(key.tonic, m21.pitch.Pitch("C"))
        elif key.mode == "minor":
            interval = m21.interval.Interval(key.tonic, m21.pitch.Pitch("A"))

        # transpose song by calculated interval
        tranposed_song = song.transpose(interval)
        return tranposed_song.chordify()

    def encode_song(self, song, time_step=0.25):
        """
        Converts a score into a time-series-like music representation. Each item in the encoded list represents 'min_duration'
        quarter lengths. The symbols used at each step are: integers for MIDI notes, 'r' for representing a rest, and '_'
        for representing notes/rests that are carried over into a new time step. Here's a sample encoding:

            ["r", "_", "60", "_", "_", "_", "72" "_"]

        :param song (m21 stream): Piece to encode
        :param time_step (float): Duration of each time step in quarter length
        :return:
        """
        #print("Encoding Song...")
        encoded_song = []

        for event in song.flat.notesAndRests:

            # handle notes
            if isinstance(event, m21.note.Note):
                symbol = event.pitch.midi # 60
            # handle rests
            elif isinstance(event, m21.note.Rest):
                symbol = "r"
            elif isinstance(event, m21.chord.Chord):
                symbol = '.'.join(str(n) for n in event.normalOrder)

            # convert the note/rest into time series notation
            steps = int(event.duration.quarterLength / time_step)
            for step in range(steps):

                # if it's the first time we see a note/rest, let's encode it. Otherwise, it means we're carrying the same
                # symbol in a new time step
                if step == 0:
                    encoded_song.append(symbol)
                else:
                    encoded_song.append("_")

        # cast encoded song to str
        encoded_song = " ".join(map(str, encoded_song))

        return encoded_song

    def convert_songs_to_int(self, songs: str, mapping_path:str):
        """ 
        Maps the symbol in the song to an integer as dictated by the mappings.json file you create
        earlier in training

        :param songs (str): The giant song string you are currently using
        :mapping_path (str): Path to your mappins.json file
        :return int_songs
        """
        int_songs = []
        
        # load mappings
        # TODO: Make the file_helper do this
        with open(mapping_path, "r") as fp:
            mappings = json.load(fp)

        # cast songs string to a list
        songs = songs.split()

        # map sings to int
        for symbol in songs:
            # TODO: Add some defensive coding strats here if key !exists 
            int_songs.append(mappings[symbol])

        return int_songs

    def create_mapping(self, songs: str, mapping_path: str) -> None:
        """
        Creates a json file that maps the symbols in the song dataset onto integers
        This mappins file is EXTREMELY important for further training, dont lose it!

        :param songs (str): String with all songs
        :param mapping_path (str): Path where to save mapping
        :return:
        """
        mappings = {}

        # identify the vocabulary
        songs = songs.split()
        vocabulary = list(set(songs))

        # create mappings
        for i, symbol in enumerate(vocabulary):
            mappings[symbol] = i

        # save voabulary to a json file
        # TODO: Have the file_helper do this
        with open(mapping_path, "w+") as fp:
            json.dump(mappings, fp, indent=4)

    def generate_training_sequences(self, sequence_length: int, single_file_dataset_path: str, mapping_path: str):
        """ 
        This creates representations of our data that can now be fed to an LSTM model

        :param sequence_length (int): The length of the "sliding window" we're using to refeed samples
        :param single_file_dataset_path (str): The file generated by create_single_file_dataset
        :param mapping_path (str): The mapping file that maps symbols to ints
        :return inputs, targets (3D Numpy Array): This is a 3d Numpy array/tensor for the model
        """
        # What this is trying to create in the model:
        # [11, 12, 13, 14, ...] -> inputs:[11, 12],  target:[13]

        # load songs and map them to int
        songs = self._file_helper.load_file_as_str(single_file_dataset_path)
        int_songs = self.convert_songs_to_int(songs, mapping_path)

        # generate the training sequences
        # 100 symbols, seq_len = 64, 100 - 64 = 36 sequences we can generate
        inputs = []
        targets = []
        num_sequences = len(int_songs) - sequence_length

        # This loops generates the training slices plus the target to predict
        for i in range(num_sequences):
            inputs.append(int_songs[i:i+sequence_length])
            targets.append(int_songs[i+sequence_length])

        # one-hot encode the sequences
        # inputs: (# of sequences, sequence length, vocabulary size)
        vocabulary_size = len(set(int_songs))
        inputs = keras.utils.to_categorical(inputs, num_classes=vocabulary_size, dtype=np.uint8)
        targets = np.array(targets)

        # Inputs will be a 3D Numpy array as demonstrated above
        return inputs, targets


    def create_single_file_dataset(self, encoded_song_path: str, file_dataset_path: str, sequence_length: int) -> str:
        """
        Generates a file collating all the encoded songs and adding new piece delimiters. It then saves that to disc and returns the song

        :param dataset_path (str): Path to folder containing the encoded songs
        :param file_dataset_path (str): Path to file for saving songs in single txt file
        :param sequence_length (int): # of time steps to be considered for training
        :return songs (str): String containing all songs in dataset + delimiters
        """

        new_song_delimiter = "/ " * sequence_length
        songs = ""

        # load encoded songs and add delimiters
        for path, _, files in os.walk(encoded_song_path):
            for file in files:
                file_path = os.path.join(path, file)
                song = self._file_helper.load_file_as_str(file_path)
                songs = songs + song + " " + new_song_delimiter

        # remove empty space from last character of string
        songs = songs[:-1]

        # save string that contains all the dataset
        # TODO: Move to file helper + add defensive checks
        with open(file_dataset_path, "w+") as fp:
            fp.write(songs)

        return songs

    def preprocess_songs(self, dataset_path: str, song_txt_path: str, major_key: str, minor_key: str, file_type: str) -> None:
        """
        A method that encompasses many of the preprocessing operations needed for converting
        the songs to a helpful representation for our RNN/LSTM/Time Series centric models

        :param dataset_path (str): The complete path to the dataset you want to load
        :param song_text_path (str): The complete path where the song_txt file will be saved
        :param major_key (str): What major key we transpose songs to
        :param minor_key (str): What minor key we transpose songs to
        :return None: This method returns nothing
        """

        # load folk songs
        #print("Loading songs...")
        songs = self.load_songs(dataset_path, file_type)
        print(f"Loaded {len(songs)} songs.")

        for i, song in enumerate(songs):
            # transpose songs to the major/minor key we want
            song = self.transpose_song(song, major_key, minor_key)

            # encode songs with music time series representation
            encoded_song = self.encode_song(song)

            # save songs to text file
            save_path = os.path.join(song_txt_path, str(i))
            # TODO: Have file helper do this + defensive checks
            with open(save_path, "w+") as fp:
                fp.write(encoded_song)

    # TODO: Ensure this is as genric as possible and applicate 
    def song_data_pipeline(self, pipeline_config: dict) -> None:
        """ 
        A single method that encapsulates the entire preprocessing pipeline for files. 

        :param pipeline_config (dict): A dict containing all the parameters and arguments for the methods being called.
        :return None: This method returns nothing
        """

        # TODO: Add better defensive coding, throughout the entire method really
        if (len(pipeline_config.keys()) < 6):
             raise Exception("Not enough keys, returning...")
        
        print("Entering song preprocessing...")
        self.preprocess_songs(
           pipeline_config['DATASET_PATH'], 
           pipeline_config['ENCODED_SONG_PATH'],
           pipeline_config['MAJOR_KEY'],
           pipeline_config['MINOR_KEY'],
           pipeline_config['FILE_TYPE']
        )
        
        songs = self.create_single_file_dataset(
            pipeline_config['ENCODED_SONG_PATH'],
           pipeline_config['SINGLE_FILE_DATASET_PATH'],
           pipeline_config['SEQUENCE_LENGTH']
        )

        self.create_mapping(songs, pipeline_config['MAPPING_PATH'])
        print("Finished preprocessing songs!")

        print("Generating training data...")
        inputs, targets = self.generate_training_sequences(
            pipeline_config['SEQUENCE_LENGTH'],
            pipeline_config['SINGLE_FILE_DATASET_PATH'],
            pipeline_config['MAPPING_PATH']
        )

        print("Finishing creating training data. Now returning....")
        return inputs, targets

# %%
# TODO: Make the output neurons return from the music_helper where the data processing
# actually happens
LOSS_FUNC = "sparse_categorical_crossentropy"
LEARNING_RATE = 0.001
BATCH_SIZE = 16
NUM_NEURONS = [256] # number of neurons in the eternal layers
ROOT_PATH = Path.cwd()
SAVE_MODEL_PATH = f"{ROOT_PATH}/JazzDrums.h5"

# Used with the music helper class
pipeline_config = {
    'DATASET_PATH': f"{ROOT_PATH}/data",
    'ENCODED_SONG_PATH': f"{ROOT_PATH}/processed_songs/",
    'MAJOR_KEY': "C",
    'MINOR_KEY': "A",
    'SINGLE_FILE_DATASET_PATH': f"{ROOT_PATH}/massive_song_file_data.txt",
    'MAPPING_PATH': f"{ROOT_PATH}/song_mappings.json",
    'SEQUENCE_LENGTH': 64,
    'FILE_TYPE': "mid",
    'STAGE': 0
}

# %%
file_helper = FileHelper()
music_helper = MusicHelper(file_helper)
# Out:
# MusicHelper has been created...

# %%
inputs, targets = music_helper.song_data_pipeline(
            pipeline_config
        )
# Out:
# Entering song preprocessing...
# Loading songs....
# Loaded 400 songs.
# Finished preprocessing songs!
# Generating training data...
# Finishing creating training data. Now returning....

# %%
def build_model(output_neurons, num_neurons, loss, learning_rate):

    # Create the model architecture, functionally!
    # If we say None for the shape, it lets us have any length input for the time steps
    # This is important because we might wanna feed it different length premade sequences
    input = keras.layers.Input(shape=(None, output_neurons))
    x = keras.layers.LSTM(num_neurons[0]*2)(input) # This links the layers together
    x = keras.layers.Dropout(0.2)(x)
    dense = keras.layers.Dense(num_neurons[0], activation="relu")(x)
    dense = keras.layers.Dropout(0.3)(dense)
    dense = keras.layers.Dense(num_neurons[0]//2, activation="relu")(dense)
    dense = keras.layers.Dropout(0.3)(dense)
    output = keras.layers.Dense(output_neurons, activation="softmax")(dense)

    # compile the model
    model = keras.Model(input, output)
    model.compile(loss=loss,
                optimizer=keras.optimizers.Adam(lr=learning_rate),
                metrics=["accuracy"])

    model.summary()

    return model

# %%
# set any callbacks
checkpoint_path = f"{ROOT_PATH}/checkpoints/cp.ckpt"

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
OUTPUT_NEURONS = len(file_helper.loadJSON("./song_mappings.json").keys())
OUTPUT_NEURONS # Equal to vocabulary size from the mapping.json
# Out:
# 262

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5543ef22fa1a> in <module>
# ----> 1 model.load_weights(checkpoint_path)
#
# NameError: name 'model' is not defined

# %%
model = build_model(OUTPUT_NEURONS, NUM_NEURONS, LOSS_FUNC, LEARNING_RATE)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 262)]       0
# _________________________________________________________________
# lstm (LSTM)                  (None, 512)               1587200
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 262)               33798
# =================================================================
# Total params: 1,785,222
# Trainable params: 1,785,222
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.load_weights(checkpoint_path)

# %%
TOTAL_EPOCHS = 180
model.fit(inputs, targets, epochs=TOTAL_EPOCHS, batch_size=BATCH_SIZE, callbacks=[cp_callback])

# save the model
model.save(SAVE_MODEL_PATH)
# Out:
# Epoch 1/180
# 2625/2625 [==============================] - ETA: 0s - loss: 1.9000 - accuracy: 0.6784
# Epoch 00001: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 1.9000 - accuracy: 0.6784
# Epoch 2/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 1.3683 - accuracy: 0.6941
# Epoch 00002: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 1.3683 - accuracy: 0.6942
# Epoch 3/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 1.2785 - accuracy: 0.7234
# Epoch 00003: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 1.2783 - accuracy: 0.7235
# Epoch 4/180
# 2625/2625 [==============================] - ETA: 0s - loss: 1.2160 - accuracy: 0.7422
# Epoch 00004: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 1.2160 - accuracy: 0.7422
# Epoch 5/180
# 2625/2625 [==============================] - ETA: 0s - loss: 1.1615 - accuracy: 0.7511
# Epoch 00005: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 1.1615 - accuracy: 0.7511
# Epoch 6/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 1.1145 - accuracy: 0.7586
# Epoch 00006: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 1.1146 - accuracy: 0.7587
# Epoch 7/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 1.0721 - accuracy: 0.7656
# Epoch 00007: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 1.0724 - accuracy: 0.7655
# Epoch 8/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 1.0435 - accuracy: 0.7728
# Epoch 00008: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 1.0436 - accuracy: 0.7728
# Epoch 9/180
# 2625/2625 [==============================] - ETA: 0s - loss: 1.0016 - accuracy: 0.7783
# Epoch 00009: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 1.0016 - accuracy: 0.7783
# Epoch 10/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.9768 - accuracy: 0.7825
# Epoch 00010: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.9768 - accuracy: 0.7825
# Epoch 11/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.9503 - accuracy: 0.7857
# Epoch 00011: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.9503 - accuracy: 0.7857
# Epoch 12/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.9275 - accuracy: 0.7885
# Epoch 00012: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.9275 - accuracy: 0.7886
# Epoch 13/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.9029 - accuracy: 0.7938
# Epoch 00013: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.9035 - accuracy: 0.7937
# Epoch 14/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.8818 - accuracy: 0.7966
# Epoch 00014: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.8818 - accuracy: 0.7966
# Epoch 15/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.8681 - accuracy: 0.7994
# Epoch 00015: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.8680 - accuracy: 0.7994
# Epoch 16/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.8808 - accuracy: 0.7955
# Epoch 00016: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.8808 - accuracy: 0.7955
# Epoch 17/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.8269 - accuracy: 0.8061
# Epoch 00017: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.8269 - accuracy: 0.8061
# Epoch 18/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.8209 - accuracy: 0.8074
# Epoch 00018: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.8209 - accuracy: 0.8074
# Epoch 19/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.7988 - accuracy: 0.8107
# Epoch 00019: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.7988 - accuracy: 0.8107
# Epoch 20/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.7898 - accuracy: 0.8118
# Epoch 00020: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.7898 - accuracy: 0.8118
# Epoch 21/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.7711 - accuracy: 0.8153
# Epoch 00021: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.7711 - accuracy: 0.8153
# Epoch 22/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.7602 - accuracy: 0.8179
# Epoch 00022: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.7601 - accuracy: 0.8179
# Epoch 23/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.7449 - accuracy: 0.8215
# Epoch 00023: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.7449 - accuracy: 0.8214
# Epoch 24/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.9545 - accuracy: 0.8269
# Epoch 00024: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.9545 - accuracy: 0.8269
# Epoch 25/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.7095 - accuracy: 0.8307
# Epoch 00025: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.7098 - accuracy: 0.8306
# Epoch 26/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.6717 - accuracy: 0.8366
# Epoch 00026: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.6717 - accuracy: 0.8366
# Epoch 27/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.6622 - accuracy: 0.8366
# Epoch 00027: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.6622 - accuracy: 0.8366
# Epoch 28/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.6604 - accuracy: 0.8382
# Epoch 00028: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.6606 - accuracy: 0.8381
# Epoch 29/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.6559 - accuracy: 0.8377
# Epoch 00029: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.6557 - accuracy: 0.8378
# Epoch 30/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.6665 - accuracy: 0.8382
# Epoch 00030: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.6665 - accuracy: 0.8382
# Epoch 31/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.6758 - accuracy: 0.8358
# Epoch 00031: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.6755 - accuracy: 0.8359
# Epoch 32/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.6704 - accuracy: 0.8372
# Epoch 00032: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.6705 - accuracy: 0.8372
# Epoch 33/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.6757 - accuracy: 0.8354
# Epoch 00033: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.6754 - accuracy: 0.8355
# Epoch 34/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.6564 - accuracy: 0.8406
# Epoch 00034: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.6567 - accuracy: 0.8406
# Epoch 35/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.6445 - accuracy: 0.8415
# Epoch 00035: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.6448 - accuracy: 0.8415
# Epoch 36/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.6428 - accuracy: 0.8433
# Epoch 00036: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 48s 18ms/step - loss: 0.6431 - accuracy: 0.8432
# Epoch 37/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.6307 - accuracy: 0.8441
# Epoch 00037: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 51s 20ms/step - loss: 0.6307 - accuracy: 0.8441
# Epoch 38/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.6262 - accuracy: 0.8465
# Epoch 00038: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.6260 - accuracy: 0.8465
# Epoch 39/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.6202 - accuracy: 0.8478
# Epoch 00039: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.6203 - accuracy: 0.8478
# Epoch 40/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.6119 - accuracy: 0.8500
# Epoch 00040: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 49s 19ms/step - loss: 0.6119 - accuracy: 0.8500
# Epoch 41/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.5964 - accuracy: 0.8526
# Epoch 00041: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 50s 19ms/step - loss: 0.5968 - accuracy: 0.8525
# Epoch 42/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.5969 - accuracy: 0.8531
# Epoch 00042: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 48s 18ms/step - loss: 0.5969 - accuracy: 0.8531
# Epoch 43/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.5981 - accuracy: 0.8517
# Epoch 00043: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.5979 - accuracy: 0.8518
# Epoch 44/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.5872 - accuracy: 0.8542
# Epoch 00044: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 48s 18ms/step - loss: 0.5871 - accuracy: 0.8542
# Epoch 45/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.5832 - accuracy: 0.8552
# Epoch 00045: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 50s 19ms/step - loss: 0.5832 - accuracy: 0.8552
# Epoch 46/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.5717 - accuracy: 0.8576
# Epoch 00046: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.5717 - accuracy: 0.8576
# Epoch 47/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.5711 - accuracy: 0.8578
# Epoch 00047: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.5711 - accuracy: 0.8578
# Epoch 48/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.5687 - accuracy: 0.8588
# Epoch 00048: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.5688 - accuracy: 0.8588
# Epoch 49/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.5556 - accuracy: 0.8618
# Epoch 00049: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.5554 - accuracy: 0.8618
# Epoch 50/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.5476 - accuracy: 0.8633
# Epoch 00050: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.5479 - accuracy: 0.8632
# Epoch 51/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.5423 - accuracy: 0.8643
# Epoch 00051: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.5424 - accuracy: 0.8643
# Epoch 52/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.5517 - accuracy: 0.8638
# Epoch 00052: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.5518 - accuracy: 0.8638
# Epoch 53/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.5548 - accuracy: 0.8634
# Epoch 00053: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.5547 - accuracy: 0.8634
# Epoch 54/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.5238 - accuracy: 0.8686
# Epoch 00054: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.5237 - accuracy: 0.8686
# Epoch 55/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.5297 - accuracy: 0.8683
# Epoch 00055: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.5299 - accuracy: 0.8682
# Epoch 56/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.5302 - accuracy: 0.8671
# Epoch 00056: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 49s 19ms/step - loss: 0.5301 - accuracy: 0.8671
# Epoch 57/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.5259 - accuracy: 0.8704
# Epoch 00057: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.5259 - accuracy: 0.8704
# Epoch 58/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.5228 - accuracy: 0.8697
# Epoch 00058: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.5228 - accuracy: 0.8697
# Epoch 59/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.5115 - accuracy: 0.8736 ETA
# Epoch 00059: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 48s 18ms/step - loss: 0.5115 - accuracy: 0.8736
# Epoch 60/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.5089 - accuracy: 0.8706
# Epoch 00060: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.5091 - accuracy: 0.8706
# Epoch 61/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.4997 - accuracy: 0.8756
# Epoch 00061: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4999 - accuracy: 0.8755
# Epoch 62/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.5072 - accuracy: 0.8738
# Epoch 00062: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.5072 - accuracy: 0.8738
# Epoch 63/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4966 - accuracy: 0.8765
# Epoch 00063: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4966 - accuracy: 0.8765
# Epoch 64/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.4924 - accuracy: 0.8777
# Epoch 00064: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4926 - accuracy: 0.8777
# Epoch 65/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4971 - accuracy: 0.8763
# Epoch 00065: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4971 - accuracy: 0.8763
# Epoch 66/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4915 - accuracy: 0.8762
# Epoch 00066: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4915 - accuracy: 0.8762
# Epoch 67/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.4748 - accuracy: 0.8806
# Epoch 00067: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4747 - accuracy: 0.8806
# Epoch 68/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.4966 - accuracy: 0.8779
# Epoch 00068: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4964 - accuracy: 0.8780
# Epoch 69/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4815 - accuracy: 0.8805
# Epoch 00069: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4813 - accuracy: 0.8806
# Epoch 70/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4880 - accuracy: 0.8800
# Epoch 00070: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4884 - accuracy: 0.8799
# Epoch 71/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4767 - accuracy: 0.8824
# Epoch 00071: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4767 - accuracy: 0.8824
# Epoch 72/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.4763 - accuracy: 0.8814
# Epoch 00072: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4762 - accuracy: 0.8814
# Epoch 73/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4799 - accuracy: 0.8809
# Epoch 00073: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4799 - accuracy: 0.8809
# Epoch 74/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4628 - accuracy: 0.8850
# Epoch 00074: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4628 - accuracy: 0.8850
# Epoch 75/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4777 - accuracy: 0.8830
# Epoch 00075: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4777 - accuracy: 0.8830
# Epoch 76/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.4550 - accuracy: 0.8857
# Epoch 00076: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4553 - accuracy: 0.8856
# Epoch 77/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4628 - accuracy: 0.8854
# Epoch 00077: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4628 - accuracy: 0.8855
# Epoch 78/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4727 - accuracy: 0.8836
# Epoch 00078: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4726 - accuracy: 0.8836
# Epoch 79/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.8867
# Epoch 00079: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4590 - accuracy: 0.8867
# Epoch 80/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.4582 - accuracy: 0.8868
# Epoch 00080: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4581 - accuracy: 0.8868
# Epoch 81/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4587 - accuracy: 0.8870
# Epoch 00081: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4586 - accuracy: 0.8870
# Epoch 82/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4602 - accuracy: 0.8884
# Epoch 00082: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4602 - accuracy: 0.8884
# Epoch 83/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4523 - accuracy: 0.8883
# Epoch 00083: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4522 - accuracy: 0.8883
# Epoch 84/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4561 - accuracy: 0.8884 ETA: 0s - los
# Epoch 00084: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4561 - accuracy: 0.8884
# Epoch 85/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.4485 - accuracy: 0.8886 ETA: 0s - loss: 0.4463
# Epoch 00085: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 44s 17ms/step - loss: 0.4484 - accuracy: 0.8885
# Epoch 86/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4500 - accuracy: 0.8892
# Epoch 00086: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4500 - accuracy: 0.8891
# Epoch 87/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4393 - accuracy: 0.8923
# Epoch 00087: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4393 - accuracy: 0.8923
# Epoch 88/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.4351 - accuracy: 0.8941
# Epoch 00088: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4350 - accuracy: 0.8941
# Epoch 89/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4306 - accuracy: 0.8924
# Epoch 00089: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4306 - accuracy: 0.8924
# Epoch 90/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4742 - accuracy: 0.8893
# Epoch 00090: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4741 - accuracy: 0.8893
# Epoch 91/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4588 - accuracy: 0.8934
# Epoch 00091: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4587 - accuracy: 0.8934
# Epoch 92/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4405 - accuracy: 0.8914
# Epoch 00092: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4407 - accuracy: 0.8914
# Epoch 93/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4306 - accuracy: 0.8929
# Epoch 00093: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4305 - accuracy: 0.8929
# Epoch 94/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4333 - accuracy: 0.8933
# Epoch 00094: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4332 - accuracy: 0.8933
# Epoch 95/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4470 - accuracy: 0.8921
# Epoch 00095: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4470 - accuracy: 0.8920
# Epoch 96/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4368 - accuracy: 0.8938
# Epoch 00096: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4368 - accuracy: 0.8938
# Epoch 97/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4342 - accuracy: 0.8943
# Epoch 00097: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.4342 - accuracy: 0.8943
# Epoch 98/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4275 - accuracy: 0.8942
# Epoch 00098: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4275 - accuracy: 0.8942
# Epoch 99/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4197 - accuracy: 0.8971
# Epoch 00099: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4196 - accuracy: 0.8971
# Epoch 100/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3904 - accuracy: 0.9020
# Epoch 00100: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3904 - accuracy: 0.9020
# Epoch 101/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.9010
# Epoch 00101: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.3989 - accuracy: 0.9010
# Epoch 102/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4090 - accuracy: 0.9000
# Epoch 00102: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4089 - accuracy: 0.9000
# Epoch 103/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4256 - accuracy: 0.8963
# Epoch 00103: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4259 - accuracy: 0.8962
# Epoch 104/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4323 - accuracy: 0.8953
# Epoch 00104: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.4324 - accuracy: 0.8952
# Epoch 105/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4225 - accuracy: 0.8972
# Epoch 00105: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4226 - accuracy: 0.8972
# Epoch 106/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4186 - accuracy: 0.8986
# Epoch 00106: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4184 - accuracy: 0.8987
# Epoch 107/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4371 - accuracy: 0.8955
# Epoch 00107: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4372 - accuracy: 0.8954
# Epoch 108/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4109 - accuracy: 0.8988
# Epoch 00108: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4109 - accuracy: 0.8988
# Epoch 109/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4110 - accuracy: 0.8989
# Epoch 00109: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4109 - accuracy: 0.8989
# Epoch 110/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4347 - accuracy: 0.8971
# Epoch 00110: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4345 - accuracy: 0.8972
# Epoch 111/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4199 - accuracy: 0.8989
# Epoch 00111: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4198 - accuracy: 0.8988
# Epoch 112/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4504 - accuracy: 0.8970
# Epoch 00112: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4502 - accuracy: 0.8970
# Epoch 113/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4281 - accuracy: 0.8996
# Epoch 00113: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4286 - accuracy: 0.8996
# Epoch 114/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4151 - accuracy: 0.8993
# Epoch 00114: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4151 - accuracy: 0.8993
# Epoch 115/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4127 - accuracy: 0.9015
# Epoch 00115: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4126 - accuracy: 0.9015
# Epoch 116/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4110 - accuracy: 0.9009
# Epoch 00116: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4110 - accuracy: 0.9009
# Epoch 117/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4212 - accuracy: 0.8993
# Epoch 00117: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 50s 19ms/step - loss: 0.4212 - accuracy: 0.8994
# Epoch 118/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4060 - accuracy: 0.9019
# Epoch 00118: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 52s 20ms/step - loss: 0.4063 - accuracy: 0.9018
# Epoch 119/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4190 - accuracy: 0.8992
# Epoch 00119: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.4190 - accuracy: 0.8992
# Epoch 120/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4280 - accuracy: 0.8995
# Epoch 00120: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4280 - accuracy: 0.8995
# Epoch 121/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4283 - accuracy: 0.8987
# Epoch 00121: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4283 - accuracy: 0.8987
# Epoch 122/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.9035
# Epoch 00122: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3971 - accuracy: 0.9035
# Epoch 123/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4061 - accuracy: 0.9005
# Epoch 00123: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4059 - accuracy: 0.9005
# Epoch 124/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4084 - accuracy: 0.9026
# Epoch 00124: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4084 - accuracy: 0.9026
# Epoch 125/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4224 - accuracy: 0.9009
# Epoch 00125: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4225 - accuracy: 0.9010
# Epoch 126/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4002 - accuracy: 0.9027
# Epoch 00126: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4002 - accuracy: 0.9027
# Epoch 127/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4118 - accuracy: 0.9024
# Epoch 00127: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.4118 - accuracy: 0.9024
# Epoch 128/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4092 - accuracy: 0.9022
# Epoch 00128: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4092 - accuracy: 0.9022
# Epoch 129/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.3947 - accuracy: 0.9034
# Epoch 00129: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3949 - accuracy: 0.9033
# Epoch 130/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4102 - accuracy: 0.9003
# Epoch 00130: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4101 - accuracy: 0.9003
# Epoch 131/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3919 - accuracy: 0.9047
# Epoch 00131: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3919 - accuracy: 0.9047
# Epoch 132/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3945 - accuracy: 0.9053
# Epoch 00132: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3945 - accuracy: 0.9053
# Epoch 133/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4149 - accuracy: 0.9003
# Epoch 00133: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4149 - accuracy: 0.9003
# Epoch 134/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4085 - accuracy: 0.9020
# Epoch 00134: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4085 - accuracy: 0.9020
# Epoch 135/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4089 - accuracy: 0.9031
# Epoch 00135: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.4089 - accuracy: 0.9032
# Epoch 136/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.3941 - accuracy: 0.9046
# Epoch 00136: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3942 - accuracy: 0.9045
# Epoch 137/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4051 - accuracy: 0.9007
# Epoch 00137: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4051 - accuracy: 0.9007
# Epoch 138/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4120 - accuracy: 0.9022
# Epoch 00138: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4120 - accuracy: 0.9022
# Epoch 139/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4181 - accuracy: 0.9026
# Epoch 00139: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4181 - accuracy: 0.9026
# Epoch 140/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4113 - accuracy: 0.9022
# Epoch 00140: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4112 - accuracy: 0.9022
# Epoch 141/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4015 - accuracy: 0.9039
# Epoch 00141: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4015 - accuracy: 0.9039
# Epoch 142/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.3959 - accuracy: 0.9049
# Epoch 00142: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.3962 - accuracy: 0.9049
# Epoch 143/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4187 - accuracy: 0.9018
# Epoch 00143: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4187 - accuracy: 0.9018
# Epoch 144/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.3934 - accuracy: 0.9047
# Epoch 00144: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.3934 - accuracy: 0.9047
# Epoch 145/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3914 - accuracy: 0.9059
# Epoch 00145: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.3914 - accuracy: 0.9059
# Epoch 146/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4118 - accuracy: 0.9034
# Epoch 00146: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4118 - accuracy: 0.9034
# Epoch 147/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.4098 - accuracy: 0.9037
# Epoch 00147: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4098 - accuracy: 0.9037
# Epoch 148/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4010 - accuracy: 0.9044
# Epoch 00148: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4011 - accuracy: 0.9044
# Epoch 149/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4133 - accuracy: 0.9049
# Epoch 00149: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4131 - accuracy: 0.9049
# Epoch 150/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4112 - accuracy: 0.9025
# Epoch 00150: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4112 - accuracy: 0.9025
# Epoch 151/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.3902 - accuracy: 0.9060
# Epoch 00151: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.3900 - accuracy: 0.9060
# Epoch 152/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4114 - accuracy: 0.9047
# Epoch 00152: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4114 - accuracy: 0.9047
# Epoch 153/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4079 - accuracy: 0.9044
# Epoch 00153: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4078 - accuracy: 0.9045
# Epoch 154/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3924 - accuracy: 0.9071
# Epoch 00154: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.3924 - accuracy: 0.9071
# Epoch 155/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4061 - accuracy: 0.9047
# Epoch 00155: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4061 - accuracy: 0.9047
# Epoch 156/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.3913 - accuracy: 0.9053
# Epoch 00156: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3912 - accuracy: 0.9053
# Epoch 157/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.3909 - accuracy: 0.9058
# Epoch 00157: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3909 - accuracy: 0.9058
# Epoch 158/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.3975 - accuracy: 0.9033
# Epoch 00158: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3973 - accuracy: 0.9033
# Epoch 159/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4006 - accuracy: 0.9036
# Epoch 00159: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4006 - accuracy: 0.9036
# Epoch 160/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.9093
# Epoch 00160: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3793 - accuracy: 0.9093
# Epoch 161/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.9044
# Epoch 00161: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3989 - accuracy: 0.9044
# Epoch 162/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3905 - accuracy: 0.9062
# Epoch 00162: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.3905 - accuracy: 0.9062
# Epoch 163/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4112 - accuracy: 0.9047
# Epoch 00163: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4113 - accuracy: 0.9047
# Epoch 164/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3852 - accuracy: 0.9082
# Epoch 00164: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.3852 - accuracy: 0.9082
# Epoch 165/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4056 - accuracy: 0.9054
# Epoch 00165: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 18ms/step - loss: 0.4057 - accuracy: 0.9054
# Epoch 166/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.3781 - accuracy: 0.9096
# Epoch 00166: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.3781 - accuracy: 0.9096
# Epoch 167/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4296 - accuracy: 0.9026
# Epoch 00167: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4301 - accuracy: 0.9025
# Epoch 168/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.3830 - accuracy: 0.9090
# Epoch 00168: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.3829 - accuracy: 0.9091
# Epoch 169/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4042 - accuracy: 0.9065
# Epoch 00169: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4042 - accuracy: 0.9065
# Epoch 170/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4035 - accuracy: 0.9039
# Epoch 00170: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.4034 - accuracy: 0.9039
# Epoch 171/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.3828 - accuracy: 0.9088
# Epoch 00171: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.3828 - accuracy: 0.9088
# Epoch 172/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.3991 - accuracy: 0.9064
# Epoch 00172: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.3990 - accuracy: 0.9064
# Epoch 173/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4013 - accuracy: 0.9069
# Epoch 00173: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.4013 - accuracy: 0.9069
# Epoch 174/180
# 2625/2625 [==============================] - ETA: 0s - loss: 0.4050 - accuracy: 0.9047
# Epoch 00174: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 47s 18ms/step - loss: 0.4050 - accuracy: 0.9047
# Epoch 175/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.3929 - accuracy: 0.9077
# Epoch 00175: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.3932 - accuracy: 0.9076
# Epoch 176/180
# 2623/2625 [============================>.] - ETA: 0s - loss: 0.4289 - accuracy: 0.9041
# Epoch 00176: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4291 - accuracy: 0.9041
# Epoch 177/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.3832 - accuracy: 0.9087
# Epoch 00177: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.3832 - accuracy: 0.9087
# Epoch 178/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.3812 - accuracy: 0.9078
# Epoch 00178: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 45s 17ms/step - loss: 0.3813 - accuracy: 0.9078
# Epoch 179/180
# 2624/2625 [============================>.] - ETA: 0s - loss: 0.4024 - accuracy: 0.9055
# Epoch 00179: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.4023 - accuracy: 0.9056
# Epoch 180/180
# 2622/2625 [============================>.] - ETA: 0s - loss: 0.3936 - accuracy: 0.9069
# Epoch 00180: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\JazzDrums/checkpoints\cp.ckpt
# 2625/2625 [==============================] - 46s 17ms/step - loss: 0.3936 - accuracy: 0.9069
