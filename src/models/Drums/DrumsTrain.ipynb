# %%
from pathlib import Path
import tensorflow.keras as keras
import tensorflow as tf
import sys
import json
import os
import music21 as m21
import numpy as np
from typing import List
import matplotlib.pyplot as plt

# %%
class FileHelper:
    def __init__(self):
        pass

    def load_file_as_str(self, file_path: str) -> str:
        """
        Loads the file at a specificed path, returns an error otherwise
        
        :param file_path (str): The path to the file you want to load
        :return _file a str of the contents of the file
        """
        _file = ""
        try:
            with open(file_path, "r") as fp:
                _file = fp.read()
            return _file
        except Exception:
            raise Exception(f"Error reading file at: {file_path}")

    # TODO: Might not need this
    def readBytes(self, file_path) -> bytes:
        try:
            with open(file_path, "rb") as fb:
                file_bytes = fb.read()
                return file_bytes
        except Exception:
            raise Exception(f"Error trying to read bytes at: {file_path}")
            
    def loadJSON(self, file_path) -> dict:
        try:
            with open(file_path) as json_data:
                data = json.load(json_data)
            return data
        except Exception:
            raise Exception(f"Could not open file located at: {file_path}")

# %%
# durations are expressed in quarter length
ACCEPTABLE_DURATIONS = [
    0.25, # 16th note
    0.5, # 8th note
    0.75,
    1.0, # quarter note
    1.5,
    2, # half note
    3,
    4 # whole note
]

class MusicHelper:
    def __init__(self, file_helper: FileHelper, acceptable_durations=ACCEPTABLE_DURATIONS):
        """
        :param file_helper (FileHelper): This is a file_helper object to help with writing/reading files
        :param acceptable_durations (List[float]): This is the range of notes that are ok to add for the model
        :return MusicHelper: This is the constructor for the class
        """
        print("MusicHelper has been created...")
        self.acceptable_durations = acceptable_durations
        self._file_helper = file_helper

    def load_songs(self, dataset_path: str, file_type: str):
        """
        Loads all pieces of a specific file type

        :param dataset_path (str): Path to dataset
        :param file_stype (str): The file type you want to load
        :return songs (list of m21 streams): List containing all pieces
        """
        print("Loading songs....")
        songs = []
        len_file_ext = len(file_type)

        # go through all the files in dataset and load them with music21
        for path, _, files in os.walk(dataset_path):
            for file in files:

                # consider only files of the target type
                if file[-len_file_ext:] == file_type:
                    try:
                        song = m21.converter.parse(os.path.join(path, file))
                        if self.monophonic(song):
                            songs.append(song)
                    except Exception:
                        print(f"Error processing file located at: {os.path.join(path, file)}")
        return songs
    
    def monophonic(self, stream) -> bool:
        try:
            length = len(m21.instrument.partitionByInstrument(stream).parts)
        except:
            length = 0
        return length == 1

    def transpose_song(self, song, major_key: str, minor_key: str):
        """
        Transposes song to a specified major/minor key.
        If the song is in a major scale it is transposed to the specified key, vice versa

        Defaults are in place in case the programmer forgets them

        :param song (m21 stream): The song to transpose
        :param major_key (str): The musical major key you want to transpose to
        :param minor_key (str): The musical minor key you want to transpose to
        :return transposed_song (m21 stream):
        """
        #print("Transposing song....")
        # get key from the song
        parts = song.getElementsByClass(m21.stream.Part)
        measures_part0 = parts[0].getElementsByClass(m21.stream.Measure)
        key = song.analyze("key")

        # get interval for transposition. E.g., Bmaj -> Cmaj
        if key.mode == "major":
            interval = m21.interval.Interval(key.tonic, m21.pitch.Pitch("C"))
        elif key.mode == "minor":
            interval = m21.interval.Interval(key.tonic, m21.pitch.Pitch("A"))

        # transpose song by calculated interval
        tranposed_song = song.transpose(interval)
        return tranposed_song.chordify()

    def encode_song(self, song, time_step=0.25):
        """
        Converts a score into a time-series-like music representation. Each item in the encoded list represents 'min_duration'
        quarter lengths. The symbols used at each step are: integers for MIDI notes, 'r' for representing a rest, and '_'
        for representing notes/rests that are carried over into a new time step. Here's a sample encoding:

            ["r", "_", "60", "_", "_", "_", "72" "_"]

        :param song (m21 stream): Piece to encode
        :param time_step (float): Duration of each time step in quarter length
        :return:
        """
        #print("Encoding Song...")
        encoded_song = []

        for event in song.flat.notesAndRests:

            # handle notes
            if isinstance(event, m21.note.Note):
                symbol = event.pitch.midi # 60
            # handle rests
            elif isinstance(event, m21.note.Rest):
                symbol = "r"
            elif isinstance(event, m21.chord.Chord):
                symbol = '.'.join(str(n) for n in event.normalOrder)

            # convert the note/rest into time series notation
            steps = int(event.duration.quarterLength / time_step)
            for step in range(steps):

                # if it's the first time we see a note/rest, let's encode it. Otherwise, it means we're carrying the same
                # symbol in a new time step
                if step == 0:
                    encoded_song.append(symbol)
                else:
                    encoded_song.append("_")

        # cast encoded song to str
        encoded_song = " ".join(map(str, encoded_song))

        return encoded_song

    def convert_songs_to_int(self, songs: str, mapping_path:str):
        """ 
        Maps the symbol in the song to an integer as dictated by the mappings.json file you create
        earlier in training

        :param songs (str): The giant song string you are currently using
        :mapping_path (str): Path to your mappins.json file
        :return int_songs
        """
        int_songs = []
        
        # load mappings
        # TODO: Make the file_helper do this
        with open(mapping_path, "r") as fp:
            mappings = json.load(fp)

        # cast songs string to a list
        songs = songs.split()

        # map sings to int
        for symbol in songs:
            # TODO: Add some defensive coding strats here if key !exists 
            int_songs.append(mappings[symbol])

        return int_songs

    def create_mapping(self, songs: str, mapping_path: str) -> None:
        """
        Creates a json file that maps the symbols in the song dataset onto integers
        This mappins file is EXTREMELY important for further training, dont lose it!

        :param songs (str): String with all songs
        :param mapping_path (str): Path where to save mapping
        :return:
        """
        mappings = {}

        # identify the vocabulary
        songs = songs.split()
        vocabulary = list(set(songs))

        # create mappings
        for i, symbol in enumerate(vocabulary):
            mappings[symbol] = i

        # save voabulary to a json file
        # TODO: Have the file_helper do this
        with open(mapping_path, "w+") as fp:
            json.dump(mappings, fp, indent=4)

    def generate_training_sequences(self, sequence_length: int, single_file_dataset_path: str, mapping_path: str):
        """ 
        This creates representations of our data that can now be fed to an LSTM model

        :param sequence_length (int): The length of the "sliding window" we're using to refeed samples
        :param single_file_dataset_path (str): The file generated by create_single_file_dataset
        :param mapping_path (str): The mapping file that maps symbols to ints
        :return inputs, targets (3D Numpy Array): This is a 3d Numpy array/tensor for the model
        """
        # What this is trying to create in the model:
        # [11, 12, 13, 14, ...] -> inputs:[11, 12],  target:[13]

        # load songs and map them to int
        songs = self._file_helper.load_file_as_str(single_file_dataset_path)
        int_songs = self.convert_songs_to_int(songs, mapping_path)

        # generate the training sequences
        # 100 symbols, seq_len = 64, 100 - 64 = 36 sequences we can generate
        inputs = []
        targets = []
        num_sequences = len(int_songs) - sequence_length

        # This loops generates the training slices plus the target to predict
        for i in range(num_sequences):
            inputs.append(int_songs[i:i+sequence_length])
            targets.append(int_songs[i+sequence_length])

        # one-hot encode the sequences
        # inputs: (# of sequences, sequence length, vocabulary size)
        vocabulary_size = len(set(int_songs))
        inputs = keras.utils.to_categorical(inputs, num_classes=vocabulary_size, dtype=np.uint8)
        targets = np.array(targets)

        # Inputs will be a 3D Numpy array as demonstrated above
        return inputs, targets


    def create_single_file_dataset(self, encoded_song_path: str, file_dataset_path: str, sequence_length: int) -> str:
        """
        Generates a file collating all the encoded songs and adding new piece delimiters. It then saves that to disc and returns the song

        :param dataset_path (str): Path to folder containing the encoded songs
        :param file_dataset_path (str): Path to file for saving songs in single txt file
        :param sequence_length (int): # of time steps to be considered for training
        :return songs (str): String containing all songs in dataset + delimiters
        """

        new_song_delimiter = "/ " * sequence_length
        songs = ""

        # load encoded songs and add delimiters
        for path, _, files in os.walk(encoded_song_path):
            for file in files:
                file_path = os.path.join(path, file)
                song = self._file_helper.load_file_as_str(file_path)
                songs = songs + song + " " + new_song_delimiter

        # remove empty space from last character of string
        songs = songs[:-1]

        # save string that contains all the dataset
        # TODO: Move to file helper + add defensive checks
        with open(file_dataset_path, "w+") as fp:
            fp.write(songs)

        return songs

    def preprocess_songs(self, dataset_path: str, song_txt_path: str, major_key: str, minor_key: str, file_type: str) -> None:
        """
        A method that encompasses many of the preprocessing operations needed for converting
        the songs to a helpful representation for our RNN/LSTM/Time Series centric models

        :param dataset_path (str): The complete path to the dataset you want to load
        :param song_text_path (str): The complete path where the song_txt file will be saved
        :param major_key (str): What major key we transpose songs to
        :param minor_key (str): What minor key we transpose songs to
        :return None: This method returns nothing
        """

        # load folk songs
        #print("Loading songs...")
        songs = self.load_songs(dataset_path, file_type)
        print(f"Loaded {len(songs)} songs.")

        for i, song in enumerate(songs):
            # transpose songs to the major/minor key we want
            song = self.transpose_song(song, major_key, minor_key)

            # encode songs with music time series representation
            encoded_song = self.encode_song(song)

            # save songs to text file
            save_path = os.path.join(song_txt_path, str(i))
            # TODO: Have file helper do this + defensive checks
            with open(save_path, "w+") as fp:
                fp.write(encoded_song)

    # TODO: Ensure this is as genric as possible and applicate 
    def song_data_pipeline(self, pipeline_config: dict) -> None:
        """ 
        A single method that encapsulates the entire preprocessing pipeline for files. 

        :param pipeline_config (dict): A dict containing all the parameters and arguments for the methods being called.
        :return None: This method returns nothing
        """

        # TODO: Add better defensive coding, throughout the entire method really
        if (len(pipeline_config.keys()) < 6):
             raise Exception("Not enough keys, returning...")
        
        print("Entering song preprocessing...")
        self.preprocess_songs(
           pipeline_config['DATASET_PATH'], 
           pipeline_config['ENCODED_SONG_PATH'],
           pipeline_config['MAJOR_KEY'],
           pipeline_config['MINOR_KEY'],
           pipeline_config['FILE_TYPE']
        )
        
        songs = self.create_single_file_dataset(
            pipeline_config['ENCODED_SONG_PATH'],
           pipeline_config['SINGLE_FILE_DATASET_PATH'],
           pipeline_config['SEQUENCE_LENGTH']
        )

        self.create_mapping(songs, pipeline_config['MAPPING_PATH'])
        print("Finished preprocessing songs!")

        print("Generating training data...")
        inputs, targets = self.generate_training_sequences(
            pipeline_config['SEQUENCE_LENGTH'],
            pipeline_config['SINGLE_FILE_DATASET_PATH'],
            pipeline_config['MAPPING_PATH']
        )

        print("Finishing creating training data. Now returning....")
        return inputs, targets

# %%
# TODO: Make the output neurons return from the music_helper where the data processing
# actually happens
LOSS_FUNC = "sparse_categorical_crossentropy"
LEARNING_RATE = 0.001
BATCH_SIZE = 16
NUM_NEURONS = [256] # number of neurons in the eternal layers
ROOT_PATH = Path.cwd()
SAVE_MODEL_PATH = f"{ROOT_PATH}/Drums.h5"

# Used with the music helper class
pipeline_config = {
    'DATASET_PATH': f"{ROOT_PATH}/data",
    'ENCODED_SONG_PATH': f"{ROOT_PATH}/processed_songs/",
    'MAJOR_KEY': "C",
    'MINOR_KEY': "A",
    'SINGLE_FILE_DATASET_PATH': f"{ROOT_PATH}/massive_song_file_data.txt",
    'MAPPING_PATH': f"{ROOT_PATH}/song_mappings.json",
    'SEQUENCE_LENGTH': 64,
    'FILE_TYPE': "mid",
    'STAGE': 0
}

# %%
file_helper = FileHelper()
music_helper = MusicHelper(file_helper)
# Out:
# MusicHelper has been created...

# %%
inputs, targets = music_helper.song_data_pipeline(
            pipeline_config
        )
# Out:
# Entering song preprocessing...
# Loading songs....
# Loaded 606 songs.
# Finished preprocessing songs!
# Generating training data...
# Finishing creating training data. Now returning....

# %%
def build_model(output_neurons, num_neurons, loss, learning_rate):

    # Create the model architecture, functionally!
    # If we say None for the shape, it lets us have any length input for the time steps
    # This is important because we might wanna feed it different length premade sequences
    input = keras.layers.Input(shape=(None, output_neurons))
    x = keras.layers.LSTM(num_neurons[0]*2)(input) # This links the layers together
    x = keras.layers.Dropout(0.2)(x)
    dense = keras.layers.Dense(num_neurons[0], activation="relu")(x)
    dense = keras.layers.Dropout(0.3)(dense)
    dense = keras.layers.Dense(num_neurons[0]//2, activation="relu")(dense)
    dense = keras.layers.Dropout(0.3)(dense)
    output = keras.layers.Dense(output_neurons, activation="softmax")(dense)

    # compile the model
    model = keras.Model(input, output)
    model.compile(loss=loss,
                optimizer=keras.optimizers.Adam(lr=learning_rate),
                metrics=["accuracy"])

    model.summary()

    return model

# %%
# set any callbacks
checkpoint_path = f"{ROOT_PATH}/checkpoints/cp.ckpt"

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
OUTPUT_NEURONS = len(file_helper.loadJSON("./song_mappings.json").keys())
OUTPUT_NEURONS # Equal to vocabulary size from the mapping.json
# Out:
# 293

# %%
model = build_model(OUTPUT_NEURONS, NUM_NEURONS, LOSS_FUNC, LEARNING_RATE)
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, None, 293)]       0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 512)               1650688
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 293)               37797
# =================================================================
# Total params: 1,852,709
# Trainable params: 1,852,709
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.load_weights(checkpoint_path)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\py_checkpoint_reader.py in NewCheckpointReader(filepattern)
#      94   try:
# ---> 95     return CheckpointReader(compat.as_bytes(filepattern))
#      96   # TODO(b/143319754): Remove the RuntimeError casting logic once we resolve the
#
# RuntimeError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints/cp.ckpt
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-16-5543ef22fa1a> in <module>
# ----> 1 model.load_weights(checkpoint_path)
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2174     else:
#    2175       try:
# -> 2176         py_checkpoint_reader.NewCheckpointReader(filepath)
#    2177         save_format = 'tf'
#    2178       except errors_impl.DataLossError:
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\py_checkpoint_reader.py in NewCheckpointReader(filepattern)
#      97   # issue with throwing python exceptions from C++.
#      98   except RuntimeError as e:
# ---> 99     error_translator(e)
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\py_checkpoint_reader.py in error_translator(e)
#      33       'Failed to find any '
#      34       'matching files for') in error_message:
# ---> 35     raise errors_impl.NotFoundError(None, None, error_message)
#      36   elif 'Sliced checkpoints are not supported' in error_message or (
#      37       'Data type '
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints/cp.ckpt

# %%
TOTAL_EPOCHS = 200
model.fit(inputs, targets, epochs=TOTAL_EPOCHS, batch_size=BATCH_SIZE, callbacks=[cp_callback])

# save the model
model.save(SAVE_MODEL_PATH)
# Out:
# Epoch 1/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 1.1162 - accuracy: 0.7755
# Epoch 00001: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 192s 57ms/step - loss: 1.1161 - accuracy: 0.7755
# Epoch 2/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.9911 - accuracy: 0.8004
# Epoch 00002: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 187s 56ms/step - loss: 0.9911 - accuracy: 0.8004
# Epoch 3/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.8989 - accuracy: 0.8090
# Epoch 00003: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 189s 56ms/step - loss: 0.8989 - accuracy: 0.8090
# Epoch 4/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.8343 - accuracy: 0.8158
# Epoch 00004: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 188s 56ms/step - loss: 0.8342 - accuracy: 0.8158
# Epoch 5/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.7821 - accuracy: 0.8246 ETA
# Epoch 00005: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 187s 56ms/step - loss: 0.7821 - accuracy: 0.8246
# Epoch 6/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.7274 - accuracy: 0.8318
# Epoch 00006: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 188s 56ms/step - loss: 0.7274 - accuracy: 0.8318
# Epoch 7/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.6877 - accuracy: 0.8369
# Epoch 00007: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 198s 59ms/step - loss: 0.6878 - accuracy: 0.8369
# Epoch 8/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.6557 - accuracy: 0.8415
# Epoch 00008: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 195s 58ms/step - loss: 0.6556 - accuracy: 0.8415
# Epoch 9/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.6283 - accuracy: 0.8456 ETA: 0s - loss: 0.6283
# Epoch 00009: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 198s 59ms/step - loss: 0.6283 - accuracy: 0.8456
# Epoch 10/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.6033 - accuracy: 0.8503
# Epoch 00010: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 196s 58ms/step - loss: 0.6034 - accuracy: 0.8503
# Epoch 11/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.5796 - accuracy: 0.8531
# Epoch 00011: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 194s 58ms/step - loss: 0.5795 - accuracy: 0.8531
# Epoch 12/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.5591 - accuracy: 0.8566
# Epoch 00012: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 191s 57ms/step - loss: 0.5591 - accuracy: 0.8566
# Epoch 13/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.5419 - accuracy: 0.8598
# Epoch 00013: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 187s 56ms/step - loss: 0.5419 - accuracy: 0.8598
# Epoch 14/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.5294 - accuracy: 0.8624
# Epoch 00014: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 193s 57ms/step - loss: 0.5294 - accuracy: 0.8624
# Epoch 15/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.5094 - accuracy: 0.8663
# Epoch 00015: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 200s 60ms/step - loss: 0.5094 - accuracy: 0.8663
# Epoch 16/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.4957 - accuracy: 0.8699
# Epoch 00016: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 99s 29ms/step - loss: 0.4956 - accuracy: 0.8700
# Epoch 17/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.4802 - accuracy: 0.8728
# Epoch 00017: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.4801 - accuracy: 0.8728
# Epoch 18/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.4649 - accuracy: 0.8758
# Epoch 00018: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.4650 - accuracy: 0.8758
# Epoch 19/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.4537 - accuracy: 0.8776
# Epoch 00019: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.4537 - accuracy: 0.8776
# Epoch 20/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.4398 - accuracy: 0.8817
# Epoch 00020: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.4399 - accuracy: 0.8817
# Epoch 21/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.4359 - accuracy: 0.8839
# Epoch 00021: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.4359 - accuracy: 0.8839
# Epoch 22/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.4222 - accuracy: 0.8851
# Epoch 00022: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.4222 - accuracy: 0.8851
# Epoch 23/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.4141 - accuracy: 0.8888
# Epoch 00023: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.4141 - accuracy: 0.8888
# Epoch 24/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.4109 - accuracy: 0.8897
# Epoch 00024: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.4108 - accuracy: 0.8897
# Epoch 25/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3966 - accuracy: 0.8929
# Epoch 00025: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3965 - accuracy: 0.8929
# Epoch 26/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3902 - accuracy: 0.8956
# Epoch 00026: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3903 - accuracy: 0.8956
# Epoch 27/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3792 - accuracy: 0.8971
# Epoch 00027: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3792 - accuracy: 0.8971
# Epoch 28/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3764 - accuracy: 0.8979
# Epoch 00028: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3764 - accuracy: 0.8979
# Epoch 29/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3759 - accuracy: 0.8988
# Epoch 00029: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3761 - accuracy: 0.8988
# Epoch 30/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3647 - accuracy: 0.9018
# Epoch 00030: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3646 - accuracy: 0.9018
# Epoch 31/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3604 - accuracy: 0.9015
# Epoch 00031: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3604 - accuracy: 0.9015
# Epoch 32/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.3564 - accuracy: 0.9028
# Epoch 00032: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3564 - accuracy: 0.9028
# Epoch 33/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3485 - accuracy: 0.9045
# Epoch 00033: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3485 - accuracy: 0.9045
# Epoch 34/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3431 - accuracy: 0.9054
# Epoch 00034: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3432 - accuracy: 0.9054
# Epoch 35/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3400 - accuracy: 0.9071
# Epoch 00035: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3399 - accuracy: 0.9071
# Epoch 36/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3302 - accuracy: 0.9092
# Epoch 00036: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3303 - accuracy: 0.9092
# Epoch 37/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3286 - accuracy: 0.9101
# Epoch 00037: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3285 - accuracy: 0.9101
# Epoch 38/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3368 - accuracy: 0.9101
# Epoch 00038: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3369 - accuracy: 0.9100
# Epoch 39/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3340 - accuracy: 0.9116
# Epoch 00039: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3340 - accuracy: 0.9116
# Epoch 40/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3161 - accuracy: 0.9136
# Epoch 00040: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3160 - accuracy: 0.9136
# Epoch 41/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3109 - accuracy: 0.9145
# Epoch 00041: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3109 - accuracy: 0.9145
# Epoch 42/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3107 - accuracy: 0.9156
# Epoch 00042: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3108 - accuracy: 0.9156
# Epoch 43/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3132 - accuracy: 0.9153
# Epoch 00043: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3132 - accuracy: 0.9153
# Epoch 44/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3102 - accuracy: 0.9159
# Epoch 00044: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3102 - accuracy: 0.9159
# Epoch 45/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.3066 - accuracy: 0.9169
# Epoch 00045: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3066 - accuracy: 0.9169
# Epoch 46/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2997 - accuracy: 0.9181
# Epoch 00046: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2997 - accuracy: 0.9181
# Epoch 47/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3050 - accuracy: 0.9169
# Epoch 00047: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3049 - accuracy: 0.9169
# Epoch 48/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3002 - accuracy: 0.9182
# Epoch 00048: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3004 - accuracy: 0.9181
# Epoch 49/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3059 - accuracy: 0.9189
# Epoch 00049: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3059 - accuracy: 0.9189
# Epoch 50/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2954 - accuracy: 0.9188
# Epoch 00050: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2953 - accuracy: 0.9188
# Epoch 51/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3016 - accuracy: 0.9190
# Epoch 00051: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3016 - accuracy: 0.9191
# Epoch 52/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2983 - accuracy: 0.9205
# Epoch 00052: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2983 - accuracy: 0.9205
# Epoch 53/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2967 - accuracy: 0.9209
# Epoch 00053: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2967 - accuracy: 0.9209
# Epoch 54/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2886 - accuracy: 0.9236 ETA: 0s - loss: 0.2879 -
# Epoch 00054: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2887 - accuracy: 0.9235
# Epoch 55/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2890 - accuracy: 0.9233
# Epoch 00055: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2890 - accuracy: 0.9233
# Epoch 56/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2858 - accuracy: 0.9235
# Epoch 00056: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2857 - accuracy: 0.9235
# Epoch 57/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2908 - accuracy: 0.9237
# Epoch 00057: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2907 - accuracy: 0.9237
# Epoch 58/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2808 - accuracy: 0.9244
# Epoch 00058: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2808 - accuracy: 0.9244
# Epoch 59/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2849 - accuracy: 0.9239
# Epoch 00059: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2849 - accuracy: 0.9239
# Epoch 60/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2832 - accuracy: 0.9248
# Epoch 00060: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2833 - accuracy: 0.9248
# Epoch 61/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2860 - accuracy: 0.9250
# Epoch 00061: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2860 - accuracy: 0.9250
# Epoch 62/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2781 - accuracy: 0.9262
# Epoch 00062: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2783 - accuracy: 0.9261
# Epoch 63/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2780 - accuracy: 0.9253
# Epoch 00063: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2780 - accuracy: 0.9253
# Epoch 64/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2791 - accuracy: 0.9266
# Epoch 00064: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2791 - accuracy: 0.9266
# Epoch 65/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2823 - accuracy: 0.9271
# Epoch 00065: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2822 - accuracy: 0.9271
# Epoch 66/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2796 - accuracy: 0.9264
# Epoch 00066: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2795 - accuracy: 0.9264
# Epoch 67/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2773 - accuracy: 0.9264 ETA: 0s -
# Epoch 00067: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2773 - accuracy: 0.9265
# Epoch 68/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2753 - accuracy: 0.9278 ETA: 0s - loss: 0.2755 - accuracy
# Epoch 00068: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2754 - accuracy: 0.9278
# Epoch 69/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2749 - accuracy: 0.9275
# Epoch 00069: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2749 - accuracy: 0.9276
# Epoch 70/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2764 - accuracy: 0.9280
# Epoch 00070: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2764 - accuracy: 0.9280
# Epoch 71/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2843 - accuracy: 0.9268
# Epoch 00071: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2842 - accuracy: 0.9268
# Epoch 72/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2640 - accuracy: 0.9304
# Epoch 00072: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2640 - accuracy: 0.9304
# Epoch 73/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2763 - accuracy: 0.9284
# Epoch 00073: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2763 - accuracy: 0.9284
# Epoch 74/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2658 - accuracy: 0.9316 ETA: 0s - loss: 0.2
# Epoch 00074: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2658 - accuracy: 0.9316
# Epoch 75/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2720 - accuracy: 0.9288
# Epoch 00075: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2720 - accuracy: 0.9288
# Epoch 76/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2700 - accuracy: 0.9298
# Epoch 00076: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2700 - accuracy: 0.9298
# Epoch 77/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2689 - accuracy: 0.9299
# Epoch 00077: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2689 - accuracy: 0.9299
# Epoch 78/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.9301
# Epoch 00078: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2648 - accuracy: 0.9301
# Epoch 79/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2690 - accuracy: 0.9300
# Epoch 00079: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2689 - accuracy: 0.9301
# Epoch 80/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2663 - accuracy: 0.9304
# Epoch 00080: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2662 - accuracy: 0.9304
# Epoch 81/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2768 - accuracy: 0.9296
# Epoch 00081: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2768 - accuracy: 0.9296
# Epoch 82/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2664 - accuracy: 0.9310
# Epoch 00082: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2663 - accuracy: 0.9310
# Epoch 83/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2654 - accuracy: 0.9310 ETA: 0s - los
# Epoch 00083: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2655 - accuracy: 0.9310
# Epoch 84/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2709 - accuracy: 0.9310
# Epoch 00084: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2709 - accuracy: 0.9310
# Epoch 85/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2600 - accuracy: 0.9310
# Epoch 00085: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2600 - accuracy: 0.9310
# Epoch 86/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.9298
# Epoch 00086: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2745 - accuracy: 0.9298
# Epoch 87/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2691 - accuracy: 0.9305
# Epoch 00087: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2690 - accuracy: 0.9306
# Epoch 88/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2838 - accuracy: 0.9281
# Epoch 00088: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2838 - accuracy: 0.9281
# Epoch 89/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2845 - accuracy: 0.9311
# Epoch 00089: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2845 - accuracy: 0.9311
# Epoch 90/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2593 - accuracy: 0.9338
# Epoch 00090: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2592 - accuracy: 0.9338
# Epoch 91/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9375
# Epoch 00091: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2384 - accuracy: 0.9375
# Epoch 92/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2369 - accuracy: 0.9383
# Epoch 00092: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2369 - accuracy: 0.9383
# Epoch 93/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2392 - accuracy: 0.9379
# Epoch 00093: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2392 - accuracy: 0.9378
# Epoch 94/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9352
# Epoch 00094: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2493 - accuracy: 0.9352
# Epoch 95/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2614 - accuracy: 0.9334
# Epoch 00095: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2613 - accuracy: 0.9334
# Epoch 96/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2812 - accuracy: 0.9293
# Epoch 00096: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2811 - accuracy: 0.9293
# Epoch 97/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.9314
# Epoch 00097: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2731 - accuracy: 0.9314
# Epoch 98/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2934 - accuracy: 0.9311
# Epoch 00098: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2933 - accuracy: 0.9312
# Epoch 99/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2729 - accuracy: 0.9301
# Epoch 00099: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2730 - accuracy: 0.9301
# Epoch 100/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2749 - accuracy: 0.9300
# Epoch 00100: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2749 - accuracy: 0.9300
# Epoch 101/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2746 - accuracy: 0.9303
# Epoch 00101: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2746 - accuracy: 0.9303
# Epoch 102/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2640 - accuracy: 0.9320
# Epoch 00102: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2642 - accuracy: 0.9320
# Epoch 103/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2779 - accuracy: 0.9302
# Epoch 00103: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2779 - accuracy: 0.9302
# Epoch 104/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2813 - accuracy: 0.9314
# Epoch 00104: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2812 - accuracy: 0.9314
# Epoch 105/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2674 - accuracy: 0.9324
# Epoch 00105: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2673 - accuracy: 0.9325
# Epoch 106/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2747 - accuracy: 0.9321
# Epoch 00106: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2750 - accuracy: 0.9320
# Epoch 107/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2889 - accuracy: 0.9296
# Epoch 00107: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2889 - accuracy: 0.9296
# Epoch 108/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2678 - accuracy: 0.9309
# Epoch 00108: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2678 - accuracy: 0.9309
# Epoch 109/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3131 - accuracy: 0.9280
# Epoch 00109: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3130 - accuracy: 0.9280
# Epoch 110/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2716 - accuracy: 0.9322
# Epoch 00110: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2715 - accuracy: 0.9322
# Epoch 111/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2445 - accuracy: 0.9357
# Epoch 00111: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.2443 - accuracy: 0.9358
# Epoch 112/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2343 - accuracy: 0.9389
# Epoch 00112: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2343 - accuracy: 0.9389
# Epoch 113/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2344 - accuracy: 0.9398
# Epoch 00113: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2344 - accuracy: 0.9398
# Epoch 114/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.2439 - accuracy: 0.9368
# Epoch 00114: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2439 - accuracy: 0.9368
# Epoch 115/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2592 - accuracy: 0.9346
# Epoch 00115: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2592 - accuracy: 0.9346
# Epoch 116/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2728 - accuracy: 0.9324
# Epoch 00116: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2727 - accuracy: 0.9324
# Epoch 117/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2836 - accuracy: 0.9315
# Epoch 00117: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2836 - accuracy: 0.9315
# Epoch 118/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2676 - accuracy: 0.9336
# Epoch 00118: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.2676 - accuracy: 0.9336
# Epoch 119/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 3.6125 - accuracy: 0.8161
# Epoch 00119: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 3.6124 - accuracy: 0.8161
# Epoch 120/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 1.1383 - accuracy: 0.8085
# Epoch 00120: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 1.1383 - accuracy: 0.8085
# Epoch 121/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.9781 - accuracy: 0.8244 ETA: 0s - loss: 0.9779 - accuracy
# Epoch 00121: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.9781 - accuracy: 0.8245
# Epoch 122/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.7481 - accuracy: 0.8515
# Epoch 00122: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 58s 17ms/step - loss: 0.7478 - accuracy: 0.8516
# Epoch 123/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.6847 - accuracy: 0.8551
# Epoch 00123: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 58s 17ms/step - loss: 0.6846 - accuracy: 0.8551
# Epoch 124/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.7019 - accuracy: 0.8517
# Epoch 00124: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 58s 17ms/step - loss: 0.7019 - accuracy: 0.8517
# Epoch 125/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.6277 - accuracy: 0.8627
# Epoch 00125: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.6279 - accuracy: 0.8627
# Epoch 126/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.5715 - accuracy: 0.8719
# Epoch 00126: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.5715 - accuracy: 0.8719
# Epoch 127/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.9076 - accuracy: 0.8399
# Epoch 00127: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.9076 - accuracy: 0.8398
# Epoch 128/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.7376 - accuracy: 0.8414
# Epoch 00128: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.7375 - accuracy: 0.8415
# Epoch 129/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.7546 - accuracy: 0.8342
# Epoch 00129: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.7545 - accuracy: 0.8342
# Epoch 130/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.6907 - accuracy: 0.8430
# Epoch 00130: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.6907 - accuracy: 0.8430
# Epoch 131/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.6354 - accuracy: 0.8531
# Epoch 00131: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 63s 19ms/step - loss: 0.6354 - accuracy: 0.8531
# Epoch 132/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.5580 - accuracy: 0.8675
# Epoch 00132: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.5578 - accuracy: 0.8676
# Epoch 133/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.4451 - accuracy: 0.8930
# Epoch 00133: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.4452 - accuracy: 0.8930
# Epoch 134/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3661 - accuracy: 0.9103
# Epoch 00134: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 62s 18ms/step - loss: 0.3661 - accuracy: 0.9103
# Epoch 135/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3381 - accuracy: 0.9188
# Epoch 00135: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 62s 18ms/step - loss: 0.3380 - accuracy: 0.9188
# Epoch 136/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3271 - accuracy: 0.9214
# Epoch 00136: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 62s 18ms/step - loss: 0.3271 - accuracy: 0.9214
# Epoch 137/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3269 - accuracy: 0.9224
# Epoch 00137: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.3269 - accuracy: 0.9224
# Epoch 138/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3274 - accuracy: 0.9208
# Epoch 00138: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.3274 - accuracy: 0.9208
# Epoch 139/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3328 - accuracy: 0.9254
# Epoch 00139: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 62s 18ms/step - loss: 0.3327 - accuracy: 0.9254
# Epoch 140/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2916 - accuracy: 0.9290
# Epoch 00140: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.2916 - accuracy: 0.9290
# Epoch 141/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2751 - accuracy: 0.9324
# Epoch 00141: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.2751 - accuracy: 0.9324
# Epoch 142/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.2801 - accuracy: 0.9326
# Epoch 00142: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.2801 - accuracy: 0.9325
# Epoch 143/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2785 - accuracy: 0.9330
# Epoch 00143: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.2785 - accuracy: 0.9330
# Epoch 144/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.2986 - accuracy: 0.9295
# Epoch 00144: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.2986 - accuracy: 0.9295
# Epoch 145/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3181 - accuracy: 0.9267
# Epoch 00145: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3181 - accuracy: 0.9267
# Epoch 146/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3030 - accuracy: 0.9285
# Epoch 00146: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3030 - accuracy: 0.9285
# Epoch 147/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3052 - accuracy: 0.9265
# Epoch 00147: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3051 - accuracy: 0.9265
# Epoch 148/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2907 - accuracy: 0.9296
# Epoch 00148: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.2905 - accuracy: 0.9297
# Epoch 149/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2889 - accuracy: 0.9304
# Epoch 00149: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.2888 - accuracy: 0.9303
# Epoch 150/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3095 - accuracy: 0.9272
# Epoch 00150: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3095 - accuracy: 0.9272
# Epoch 151/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3139 - accuracy: 0.9273
# Epoch 00151: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3139 - accuracy: 0.9273
# Epoch 152/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2967 - accuracy: 0.9287
# Epoch 00152: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.2970 - accuracy: 0.9287
# Epoch 153/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3291 - accuracy: 0.9267
# Epoch 00153: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.3291 - accuracy: 0.9267
# Epoch 154/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3136 - accuracy: 0.9265
# Epoch 00154: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.3135 - accuracy: 0.9265
# Epoch 155/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3208 - accuracy: 0.9227
# Epoch 00155: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3208 - accuracy: 0.9227
# Epoch 156/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3293 - accuracy: 0.9250
# Epoch 00156: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3293 - accuracy: 0.9250
# Epoch 157/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3135 - accuracy: 0.9267
# Epoch 00157: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3136 - accuracy: 0.9267
# Epoch 158/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3332 - accuracy: 0.9271
# Epoch 00158: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3331 - accuracy: 0.9271
# Epoch 159/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.2946 - accuracy: 0.9297
# Epoch 00159: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.2948 - accuracy: 0.9297
# Epoch 160/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3302 - accuracy: 0.9243
# Epoch 00160: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3301 - accuracy: 0.9243
# Epoch 161/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3020 - accuracy: 0.9271
# Epoch 00161: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3020 - accuracy: 0.9271
# Epoch 162/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3240 - accuracy: 0.9257
# Epoch 00162: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3240 - accuracy: 0.9257
# Epoch 163/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.4460 - accuracy: 0.9190
# Epoch 00163: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.4459 - accuracy: 0.9190
# Epoch 164/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3384 - accuracy: 0.9216
# Epoch 00164: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.3385 - accuracy: 0.9216
# Epoch 165/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3066 - accuracy: 0.9266
# Epoch 00165: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.3064 - accuracy: 0.9266
# Epoch 166/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3125 - accuracy: 0.9273
# Epoch 00166: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3125 - accuracy: 0.9273
# Epoch 167/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3201 - accuracy: 0.9262
# Epoch 00167: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.3202 - accuracy: 0.9262
# Epoch 168/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.5231 - accuracy: 0.9148
# Epoch 00168: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.5231 - accuracy: 0.9148
# Epoch 169/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.5693 - accuracy: 0.8923
# Epoch 00169: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.5692 - accuracy: 0.8923
# Epoch 170/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.4802 - accuracy: 0.8961
# Epoch 00170: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.4801 - accuracy: 0.8961
# Epoch 171/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.4511 - accuracy: 0.8990
# Epoch 00171: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.4511 - accuracy: 0.8990
# Epoch 172/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.4333 - accuracy: 0.9017
# Epoch 00172: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.4332 - accuracy: 0.9017
# Epoch 173/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.4731 - accuracy: 0.8895
# Epoch 00173: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 59s 18ms/step - loss: 0.4730 - accuracy: 0.8895
# Epoch 174/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.4528 - accuracy: 0.8983
# Epoch 00174: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.4529 - accuracy: 0.8983
# Epoch 175/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.4188 - accuracy: 0.9006
# Epoch 00175: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.4186 - accuracy: 0.9006
# Epoch 176/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3774 - accuracy: 0.9085
# Epoch 00176: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3775 - accuracy: 0.9084
# Epoch 177/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.4548 - accuracy: 0.9073
# Epoch 00177: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.4546 - accuracy: 0.9073
# Epoch 178/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.4216 - accuracy: 0.9074
# Epoch 00178: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.4216 - accuracy: 0.9073
# Epoch 179/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.4466 - accuracy: 0.8999
# Epoch 00179: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.4466 - accuracy: 0.8999
# Epoch 180/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.4391 - accuracy: 0.8997
# Epoch 00180: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.4388 - accuracy: 0.8998
# Epoch 181/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3729 - accuracy: 0.9114
# Epoch 00181: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.3731 - accuracy: 0.9113
# Epoch 182/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3552 - accuracy: 0.9148
# Epoch 00182: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.3552 - accuracy: 0.9148
# Epoch 183/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3528 - accuracy: 0.9167
# Epoch 00183: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.3528 - accuracy: 0.9166
# Epoch 184/200
# 3355/3355 [==============================] - ETA: 0s - loss: 0.3425 - accuracy: 0.9186
# Epoch 00184: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.3425 - accuracy: 0.9186
# Epoch 185/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3460 - accuracy: 0.9178
# Epoch 00185: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 61s 18ms/step - loss: 0.3460 - accuracy: 0.9178
# Epoch 186/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3382 - accuracy: 0.9213
# Epoch 00186: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 60s 18ms/step - loss: 0.3381 - accuracy: 0.9213
# Epoch 187/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3210 - accuracy: 0.9241
# Epoch 00187: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 58s 17ms/step - loss: 0.3210 - accuracy: 0.9241
# Epoch 188/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3415 - accuracy: 0.9207
# Epoch 00188: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3415 - accuracy: 0.9207
# Epoch 189/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3421 - accuracy: 0.9207
# Epoch 00189: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3420 - accuracy: 0.9207
# Epoch 190/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3545 - accuracy: 0.9196
# Epoch 00190: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3545 - accuracy: 0.9196
# Epoch 191/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3391 - accuracy: 0.9224
# Epoch 00191: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3391 - accuracy: 0.9224
# Epoch 192/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3107 - accuracy: 0.9251
# Epoch 00192: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3106 - accuracy: 0.9251
# Epoch 193/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3277 - accuracy: 0.9245
# Epoch 00193: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3277 - accuracy: 0.9245
# Epoch 194/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3473 - accuracy: 0.9221 ETA: 0s - loss: 0.3480 - ac
# Epoch 00194: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3474 - accuracy: 0.9220
# Epoch 195/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3629 - accuracy: 0.9193
# Epoch 00195: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 57s 17ms/step - loss: 0.3628 - accuracy: 0.9193
# Epoch 196/200
# 3353/3355 [============================>.] - ETA: 0s - loss: 0.3539 - accuracy: 0.9176
# Epoch 00196: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3537 - accuracy: 0.9176
# Epoch 197/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3702 - accuracy: 0.9198
# Epoch 00197: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 56s 17ms/step - loss: 0.3702 - accuracy: 0.9198
# Epoch 198/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3868 - accuracy: 0.9090
# Epoch 00198: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 55s 16ms/step - loss: 0.3868 - accuracy: 0.9090
# Epoch 199/200
# 3352/3355 [============================>.] - ETA: 0s - loss: 0.3737 - accuracy: 0.9130
# Epoch 00199: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 58s 17ms/step - loss: 0.3736 - accuracy: 0.9130
# Epoch 200/200
# 3354/3355 [============================>.] - ETA: 0s - loss: 0.3539 - accuracy: 0.9169
# Epoch 00200: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\Drums/checkpoints\cp.ckpt
# 3355/3355 [==============================] - 52s 16ms/step - loss: 0.3538 - accuracy: 0.9169
