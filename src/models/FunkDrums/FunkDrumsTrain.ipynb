# %%
from pathlib import Path
import tensorflow.keras as keras
import tensorflow as tf
import sys
import json
import os
import music21 as m21
import numpy as np
from typing import List
import matplotlib.pyplot as plt

# %%
class FileHelper:
    def __init__(self):
        pass

    def load_file_as_str(self, file_path: str) -> str:
        """
        Loads the file at a specificed path, returns an error otherwise
        
        :param file_path (str): The path to the file you want to load
        :return _file a str of the contents of the file
        """
        _file = ""
        try:
            with open(file_path, "r") as fp:
                _file = fp.read()
            return _file
        except Exception:
            raise Exception(f"Error reading file at: {file_path}")

    # TODO: Might not need this
    def readBytes(self, file_path) -> bytes:
        try:
            with open(file_path, "rb") as fb:
                file_bytes = fb.read()
                return file_bytes
        except Exception:
            raise Exception(f"Error trying to read bytes at: {file_path}")
            
    def loadJSON(self, file_path) -> dict:
        try:
            with open(file_path) as json_data:
                data = json.load(json_data)
            return data
        except Exception:
            raise Exception(f"Could not open file located at: {file_path}")

# %%
# durations are expressed in quarter length
ACCEPTABLE_DURATIONS = [
    0.25, # 16th note
    0.5, # 8th note
    0.75,
    1.0, # quarter note
    1.5,
    2, # half note
    3,
    4 # whole note
]

class MusicHelper:
    def __init__(self, file_helper: FileHelper, acceptable_durations=ACCEPTABLE_DURATIONS):
        """
        :param file_helper (FileHelper): This is a file_helper object to help with writing/reading files
        :param acceptable_durations (List[float]): This is the range of notes that are ok to add for the model
        :return MusicHelper: This is the constructor for the class
        """
        print("MusicHelper has been created...")
        self.acceptable_durations = acceptable_durations
        self._file_helper = file_helper

    def load_songs(self, dataset_path: str, file_type: str):
        """
        Loads all pieces of a specific file type

        :param dataset_path (str): Path to dataset
        :param file_stype (str): The file type you want to load
        :return songs (list of m21 streams): List containing all pieces
        """
        print("Loading songs....")
        songs = []
        len_file_ext = len(file_type)

        # go through all the files in dataset and load them with music21
        for path, _, files in os.walk(dataset_path):
            for file in files:

                # consider only files of the target type
                if file[-len_file_ext:] == file_type:
                    try:
                        song = m21.converter.parse(os.path.join(path, file))
                        if self.monophonic(song):
                            songs.append(song)
                    except Exception:
                        print(f"Error processing file located at: {os.path.join(path, file)}")
        return songs
    
    def monophonic(self, stream) -> bool:
        try:
            length = len(m21.instrument.partitionByInstrument(stream).parts)
        except:
            length = 0
        return length == 1

    def transpose_song(self, song, major_key: str, minor_key: str):
        """
        Transposes song to a specified major/minor key.
        If the song is in a major scale it is transposed to the specified key, vice versa

        Defaults are in place in case the programmer forgets them

        :param song (m21 stream): The song to transpose
        :param major_key (str): The musical major key you want to transpose to
        :param minor_key (str): The musical minor key you want to transpose to
        :return transposed_song (m21 stream):
        """
        #print("Transposing song....")
        # get key from the song
        parts = song.getElementsByClass(m21.stream.Part)
        measures_part0 = parts[0].getElementsByClass(m21.stream.Measure)
        key = song.analyze("key")

        # get interval for transposition. E.g., Bmaj -> Cmaj
        if key.mode == "major":
            interval = m21.interval.Interval(key.tonic, m21.pitch.Pitch("C"))
        elif key.mode == "minor":
            interval = m21.interval.Interval(key.tonic, m21.pitch.Pitch("A"))

        # transpose song by calculated interval
        tranposed_song = song.transpose(interval)
        return tranposed_song.chordify()

    def encode_song(self, song, time_step=0.25):
        """
        Converts a score into a time-series-like music representation. Each item in the encoded list represents 'min_duration'
        quarter lengths. The symbols used at each step are: integers for MIDI notes, 'r' for representing a rest, and '_'
        for representing notes/rests that are carried over into a new time step. Here's a sample encoding:

            ["r", "_", "60", "_", "_", "_", "72" "_"]

        :param song (m21 stream): Piece to encode
        :param time_step (float): Duration of each time step in quarter length
        :return:
        """
        #print("Encoding Song...")
        encoded_song = []

        for event in song.flat.notesAndRests:

            # handle notes
            if isinstance(event, m21.note.Note):
                symbol = event.pitch.midi # 60
            # handle rests
            elif isinstance(event, m21.note.Rest):
                symbol = "r"
            elif isinstance(event, m21.chord.Chord):
                symbol = '.'.join(str(n) for n in event.normalOrder)

            # convert the note/rest into time series notation
            steps = int(event.duration.quarterLength / time_step)
            for step in range(steps):

                # if it's the first time we see a note/rest, let's encode it. Otherwise, it means we're carrying the same
                # symbol in a new time step
                if step == 0:
                    encoded_song.append(symbol)
                else:
                    encoded_song.append("_")

        # cast encoded song to str
        encoded_song = " ".join(map(str, encoded_song))

        return encoded_song

    def convert_songs_to_int(self, songs: str, mapping_path:str):
        """ 
        Maps the symbol in the song to an integer as dictated by the mappings.json file you create
        earlier in training

        :param songs (str): The giant song string you are currently using
        :mapping_path (str): Path to your mappins.json file
        :return int_songs
        """
        int_songs = []
        
        # load mappings
        # TODO: Make the file_helper do this
        with open(mapping_path, "r") as fp:
            mappings = json.load(fp)

        # cast songs string to a list
        songs = songs.split()

        # map sings to int
        for symbol in songs:
            # TODO: Add some defensive coding strats here if key !exists 
            int_songs.append(mappings[symbol])

        return int_songs

    def create_mapping(self, songs: str, mapping_path: str) -> None:
        """
        Creates a json file that maps the symbols in the song dataset onto integers
        This mappins file is EXTREMELY important for further training, dont lose it!

        :param songs (str): String with all songs
        :param mapping_path (str): Path where to save mapping
        :return:
        """
        mappings = {}

        # identify the vocabulary
        songs = songs.split()
        vocabulary = list(set(songs))

        # create mappings
        for i, symbol in enumerate(vocabulary):
            mappings[symbol] = i

        # save voabulary to a json file
        # TODO: Have the file_helper do this
        with open(mapping_path, "w+") as fp:
            json.dump(mappings, fp, indent=4)

    def generate_training_sequences(self, sequence_length: int, single_file_dataset_path: str, mapping_path: str):
        """ 
        This creates representations of our data that can now be fed to an LSTM model

        :param sequence_length (int): The length of the "sliding window" we're using to refeed samples
        :param single_file_dataset_path (str): The file generated by create_single_file_dataset
        :param mapping_path (str): The mapping file that maps symbols to ints
        :return inputs, targets (3D Numpy Array): This is a 3d Numpy array/tensor for the model
        """
        # What this is trying to create in the model:
        # [11, 12, 13, 14, ...] -> inputs:[11, 12],  target:[13]

        # load songs and map them to int
        songs = self._file_helper.load_file_as_str(single_file_dataset_path)
        int_songs = self.convert_songs_to_int(songs, mapping_path)

        # generate the training sequences
        # 100 symbols, seq_len = 64, 100 - 64 = 36 sequences we can generate
        inputs = []
        targets = []
        num_sequences = len(int_songs) - sequence_length

        # This loops generates the training slices plus the target to predict
        for i in range(num_sequences):
            inputs.append(int_songs[i:i+sequence_length])
            targets.append(int_songs[i+sequence_length])

        # one-hot encode the sequences
        # inputs: (# of sequences, sequence length, vocabulary size)
        vocabulary_size = len(set(int_songs))
        inputs = keras.utils.to_categorical(inputs, num_classes=vocabulary_size, dtype=np.uint8)
        targets = np.array(targets)

        # Inputs will be a 3D Numpy array as demonstrated above
        return inputs, targets


    def create_single_file_dataset(self, encoded_song_path: str, file_dataset_path: str, sequence_length: int) -> str:
        """
        Generates a file collating all the encoded songs and adding new piece delimiters. It then saves that to disc and returns the song

        :param dataset_path (str): Path to folder containing the encoded songs
        :param file_dataset_path (str): Path to file for saving songs in single txt file
        :param sequence_length (int): # of time steps to be considered for training
        :return songs (str): String containing all songs in dataset + delimiters
        """

        new_song_delimiter = "/ " * sequence_length
        songs = ""

        # load encoded songs and add delimiters
        for path, _, files in os.walk(encoded_song_path):
            for file in files:
                file_path = os.path.join(path, file)
                song = self._file_helper.load_file_as_str(file_path)
                songs = songs + song + " " + new_song_delimiter

        # remove empty space from last character of string
        songs = songs[:-1]

        # save string that contains all the dataset
        # TODO: Move to file helper + add defensive checks
        with open(file_dataset_path, "w+") as fp:
            fp.write(songs)

        return songs

    def preprocess_songs(self, dataset_path: str, song_txt_path: str, major_key: str, minor_key: str, file_type: str) -> None:
        """
        A method that encompasses many of the preprocessing operations needed for converting
        the songs to a helpful representation for our RNN/LSTM/Time Series centric models

        :param dataset_path (str): The complete path to the dataset you want to load
        :param song_text_path (str): The complete path where the song_txt file will be saved
        :param major_key (str): What major key we transpose songs to
        :param minor_key (str): What minor key we transpose songs to
        :return None: This method returns nothing
        """

        # load folk songs
        #print("Loading songs...")
        songs = self.load_songs(dataset_path, file_type)
        print(f"Loaded {len(songs)} songs.")

        for i, song in enumerate(songs):
            # transpose songs to the major/minor key we want
            song = self.transpose_song(song, major_key, minor_key)

            # encode songs with music time series representation
            encoded_song = self.encode_song(song)

            # save songs to text file
            save_path = os.path.join(song_txt_path, str(i))
            # TODO: Have file helper do this + defensive checks
            with open(save_path, "w+") as fp:
                fp.write(encoded_song)

    # TODO: Ensure this is as genric as possible and applicate 
    def song_data_pipeline(self, pipeline_config: dict) -> None:
        """ 
        A single method that encapsulates the entire preprocessing pipeline for files. 

        :param pipeline_config (dict): A dict containing all the parameters and arguments for the methods being called.
        :return None: This method returns nothing
        """

        # TODO: Add better defensive coding, throughout the entire method really
        if (len(pipeline_config.keys()) < 6):
             raise Exception("Not enough keys, returning...")
        
        print("Entering song preprocessing...")
        self.preprocess_songs(
           pipeline_config['DATASET_PATH'], 
           pipeline_config['ENCODED_SONG_PATH'],
           pipeline_config['MAJOR_KEY'],
           pipeline_config['MINOR_KEY'],
           pipeline_config['FILE_TYPE']
        )
        
        songs = self.create_single_file_dataset(
            pipeline_config['ENCODED_SONG_PATH'],
           pipeline_config['SINGLE_FILE_DATASET_PATH'],
           pipeline_config['SEQUENCE_LENGTH']
        )

        self.create_mapping(songs, pipeline_config['MAPPING_PATH'])
        print("Finished preprocessing songs!")

        print("Generating training data...")
        inputs, targets = self.generate_training_sequences(
            pipeline_config['SEQUENCE_LENGTH'],
            pipeline_config['SINGLE_FILE_DATASET_PATH'],
            pipeline_config['MAPPING_PATH']
        )

        print("Finishing creating training data. Now returning....")
        return inputs, targets

# %%
# TODO: Make the output neurons return from the music_helper where the data processing
# actually happens
LOSS_FUNC = "sparse_categorical_crossentropy"
LEARNING_RATE = 0.001
BATCH_SIZE = 16
NUM_NEURONS = [256] # number of neurons in the eternal layers
ROOT_PATH = Path.cwd()
SAVE_MODEL_PATH = f"{ROOT_PATH}/FunkDrums.h5"

# Used with the music helper class
pipeline_config = {
    'DATASET_PATH': f"{ROOT_PATH}/data",
    'ENCODED_SONG_PATH': f"{ROOT_PATH}/processed_songs/",
    'MAJOR_KEY': "C",
    'MINOR_KEY': "A",
    'SINGLE_FILE_DATASET_PATH': f"{ROOT_PATH}/massive_song_file_data.txt",
    'MAPPING_PATH': f"{ROOT_PATH}/song_mappings.json",
    'SEQUENCE_LENGTH': 64,
    'FILE_TYPE': "mid",
    'STAGE': 0
}

# %%
file_helper = FileHelper()
music_helper = MusicHelper(file_helper)
# Out:
# MusicHelper has been created...

# %%
inputs, targets = music_helper.song_data_pipeline(
            pipeline_config
        )
# Out:
# Entering song preprocessing...
# Loading songs....
# Loaded 300 songs.
# Finished preprocessing songs!
# Generating training data...
# Finishing creating training data. Now returning....

# %%
def build_model(output_neurons, num_neurons, loss, learning_rate):

    # Create the model architecture, functionally!
    # If we say None for the shape, it lets us have any length input for the time steps
    # This is important because we might wanna feed it different length premade sequences
    input = keras.layers.Input(shape=(None, output_neurons))
    x = keras.layers.LSTM(num_neurons[0]*2)(input) # This links the layers together
    x = keras.layers.Dropout(0.2)(x)
    dense = keras.layers.Dense(num_neurons[0], activation="relu")(x)
    dense = keras.layers.Dropout(0.3)(dense)
    dense = keras.layers.Dense(num_neurons[0]//2, activation="relu")(dense)
    dense = keras.layers.Dropout(0.3)(dense)
    output = keras.layers.Dense(output_neurons, activation="softmax")(dense)

    # compile the model
    model = keras.Model(input, output)
    model.compile(loss=loss,
                optimizer=keras.optimizers.Adam(lr=learning_rate),
                metrics=["accuracy"])

    model.summary()

    return model

# %%
# set any callbacks
checkpoint_path = f"{ROOT_PATH}/checkpoints/cp.ckpt"

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
OUTPUT_NEURONS = len(file_helper.loadJSON("./song_mappings.json").keys())
OUTPUT_NEURONS # Equal to vocabulary size from the mapping.json
# Out:
# 260

# %%
model.load_weights(checkpoint_path)

# %%
model = build_model(OUTPUT_NEURONS, NUM_NEURONS, LOSS_FUNC, LEARNING_RATE)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 260)]       0
# _________________________________________________________________
# lstm (LSTM)                  (None, 512)               1583104
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 260)               33540
# =================================================================
# Total params: 1,780,868
# Trainable params: 1,780,868
# Non-trainable params: 0
# _________________________________________________________________

# %%
TOTAL_EPOCHS = 200
model.fit(inputs, targets, epochs=TOTAL_EPOCHS, batch_size=BATCH_SIZE, callbacks=[cp_callback])

# save the model
model.save(SAVE_MODEL_PATH)
# Out:
# Epoch 1/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 1.3907 - accuracy: 0.7334
# Epoch 00001: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 1.3906 - accuracy: 0.7334
# Epoch 2/200
# 1752/1752 [==============================] - ETA: 0s - loss: 1.1137 - accuracy: 0.7563
# Epoch 00002: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 1.1137 - accuracy: 0.7563
# Epoch 3/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.9688 - accuracy: 0.7655
# Epoch 00003: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.9688 - accuracy: 0.7655
# Epoch 4/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.8901 - accuracy: 0.7804
# Epoch 00004: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.8906 - accuracy: 0.7803
# Epoch 5/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.8255 - accuracy: 0.7919
# Epoch 00005: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.8257 - accuracy: 0.7919
# Epoch 6/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.7673 - accuracy: 0.8030
# Epoch 00006: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.7670 - accuracy: 0.8030
# Epoch 7/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.7251 - accuracy: 0.8100
# Epoch 00007: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.7250 - accuracy: 0.8100
# Epoch 8/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.6915 - accuracy: 0.8161
# Epoch 00008: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.6914 - accuracy: 0.8162
# Epoch 9/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.6482 - accuracy: 0.8227
# Epoch 00009: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.6483 - accuracy: 0.8227
# Epoch 10/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.6255 - accuracy: 0.8269
# Epoch 00010: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 33s 19ms/step - loss: 0.6250 - accuracy: 0.8271
# Epoch 11/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.5914 - accuracy: 0.8346
# Epoch 00011: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.5912 - accuracy: 0.8347
# Epoch 12/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.5694 - accuracy: 0.8388
# Epoch 00012: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.5694 - accuracy: 0.8388
# Epoch 13/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.5467 - accuracy: 0.8438
# Epoch 00013: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.5467 - accuracy: 0.8438
# Epoch 14/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.5230 - accuracy: 0.8480
# Epoch 00014: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.5230 - accuracy: 0.8480
# Epoch 15/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.5022 - accuracy: 0.8539
# Epoch 00015: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.5022 - accuracy: 0.8539
# Epoch 16/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.4876 - accuracy: 0.8590
# Epoch 00016: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.4872 - accuracy: 0.8591
# Epoch 17/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.4661 - accuracy: 0.8621
# Epoch 00017: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.4663 - accuracy: 0.8621
# Epoch 18/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.4501 - accuracy: 0.8685 ETA: 0s - loss: 0.4494 - accuracy
# Epoch 00018: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.4502 - accuracy: 0.8684
# Epoch 19/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.4368 - accuracy: 0.8713
# Epoch 00019: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 35s 20ms/step - loss: 0.4371 - accuracy: 0.8712
# Epoch 20/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.4217 - accuracy: 0.8754
# Epoch 00020: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 32s 18ms/step - loss: 0.4217 - accuracy: 0.8754
# Epoch 21/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.3982 - accuracy: 0.8814
# Epoch 00021: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.3982 - accuracy: 0.8814
# Epoch 22/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.3975 - accuracy: 0.8818
# Epoch 00022: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.3975 - accuracy: 0.8818
# Epoch 23/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.3839 - accuracy: 0.8842
# Epoch 00023: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 33s 19ms/step - loss: 0.3839 - accuracy: 0.8842
# Epoch 24/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.3680 - accuracy: 0.8886
# Epoch 00024: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.3678 - accuracy: 0.8887
# Epoch 25/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.8917
# Epoch 00025: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.3614 - accuracy: 0.8917
# Epoch 26/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.3532 - accuracy: 0.8940
# Epoch 00026: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 17ms/step - loss: 0.3533 - accuracy: 0.8939
# Epoch 27/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.3430 - accuracy: 0.8967
# Epoch 00027: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 32s 19ms/step - loss: 0.3429 - accuracy: 0.8967
# Epoch 28/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.3390 - accuracy: 0.8972
# Epoch 00028: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.3389 - accuracy: 0.8972
# Epoch 29/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.3235 - accuracy: 0.9034
# Epoch 00029: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.3235 - accuracy: 0.9034
# Epoch 30/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.3178 - accuracy: 0.9049
# Epoch 00030: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.3177 - accuracy: 0.9049
# Epoch 31/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.3098 - accuracy: 0.9072
# Epoch 00031: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.3096 - accuracy: 0.9073
# Epoch 32/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.3061 - accuracy: 0.9070
# Epoch 00032: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 33s 19ms/step - loss: 0.3060 - accuracy: 0.9070
# Epoch 33/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2965 - accuracy: 0.9122
# Epoch 00033: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 17ms/step - loss: 0.2965 - accuracy: 0.9121
# Epoch 34/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.2892 - accuracy: 0.9139
# Epoch 00034: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 33s 19ms/step - loss: 0.2892 - accuracy: 0.9139
# Epoch 35/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.2824 - accuracy: 0.9156
# Epoch 00035: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2824 - accuracy: 0.9156
# Epoch 36/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2821 - accuracy: 0.9161
# Epoch 00036: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2820 - accuracy: 0.9162
# Epoch 37/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2780 - accuracy: 0.9192
# Epoch 00037: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 34s 20ms/step - loss: 0.2782 - accuracy: 0.9192
# Epoch 38/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.2687 - accuracy: 0.9199
# Epoch 00038: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 33s 19ms/step - loss: 0.2687 - accuracy: 0.9199
# Epoch 39/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2683 - accuracy: 0.9212
# Epoch 00039: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 32s 18ms/step - loss: 0.2683 - accuracy: 0.9212
# Epoch 40/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.2561 - accuracy: 0.9230
# Epoch 00040: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.2561 - accuracy: 0.9230
# Epoch 41/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2573 - accuracy: 0.9242
# Epoch 00041: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.2574 - accuracy: 0.9242
# Epoch 42/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.2467 - accuracy: 0.9274
# Epoch 00042: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 33s 19ms/step - loss: 0.2467 - accuracy: 0.9274
# Epoch 43/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2597 - accuracy: 0.9242
# Epoch 00043: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 33s 19ms/step - loss: 0.2596 - accuracy: 0.9242
# Epoch 44/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.2447 - accuracy: 0.9270
# Epoch 00044: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 33s 19ms/step - loss: 0.2449 - accuracy: 0.9269
# Epoch 45/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.2435 - accuracy: 0.9294
# Epoch 00045: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 32s 18ms/step - loss: 0.2434 - accuracy: 0.9295
# Epoch 46/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.2419 - accuracy: 0.9302
# Epoch 00046: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 32s 19ms/step - loss: 0.2419 - accuracy: 0.9302
# Epoch 47/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2374 - accuracy: 0.9310
# Epoch 00047: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2376 - accuracy: 0.9309
# Epoch 48/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.2339 - accuracy: 0.9312
# Epoch 00048: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2339 - accuracy: 0.9312
# Epoch 49/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.2393 - accuracy: 0.9330
# Epoch 00049: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2393 - accuracy: 0.9330
# Epoch 50/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.9338
# Epoch 00050: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2237 - accuracy: 0.9338
# Epoch 51/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.2273 - accuracy: 0.9339
# Epoch 00051: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2273 - accuracy: 0.9339
# Epoch 52/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.2233 - accuracy: 0.9359
# Epoch 00052: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2234 - accuracy: 0.9358
# Epoch 53/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2174 - accuracy: 0.9372
# Epoch 00053: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2174 - accuracy: 0.9372
# Epoch 54/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.2220 - accuracy: 0.9358
# Epoch 00054: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2219 - accuracy: 0.9358
# Epoch 55/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.2171 - accuracy: 0.9369
# Epoch 00055: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2170 - accuracy: 0.9370
# Epoch 56/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.2083 - accuracy: 0.9391
# Epoch 00056: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2081 - accuracy: 0.9392
# Epoch 57/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2116 - accuracy: 0.9397
# Epoch 00057: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2116 - accuracy: 0.9397
# Epoch 58/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.2019 - accuracy: 0.9397
# Epoch 00058: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2019 - accuracy: 0.9397
# Epoch 59/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.2092 - accuracy: 0.9410
# Epoch 00059: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2092 - accuracy: 0.9410
# Epoch 60/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.2064 - accuracy: 0.9400
# Epoch 00060: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2066 - accuracy: 0.9399
# Epoch 61/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2072 - accuracy: 0.9406
# Epoch 00061: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2071 - accuracy: 0.9406
# Epoch 62/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1935 - accuracy: 0.9433
# Epoch 00062: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1938 - accuracy: 0.9433
# Epoch 63/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.2042 - accuracy: 0.9423
# Epoch 00063: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2042 - accuracy: 0.9422
# Epoch 64/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.2037 - accuracy: 0.9433
# Epoch 00064: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2035 - accuracy: 0.9433
# Epoch 65/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9424
# Epoch 00065: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1986 - accuracy: 0.9424
# Epoch 66/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9440
# Epoch 00066: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1930 - accuracy: 0.9440
# Epoch 67/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1923 - accuracy: 0.9456
# Epoch 00067: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1925 - accuracy: 0.9455
# Epoch 68/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9438
# Epoch 00068: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1987 - accuracy: 0.9438
# Epoch 69/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1975 - accuracy: 0.9439
# Epoch 00069: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1974 - accuracy: 0.9439
# Epoch 70/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9465
# Epoch 00070: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1967 - accuracy: 0.9465
# Epoch 71/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1895 - accuracy: 0.9469
# Epoch 00071: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1895 - accuracy: 0.9469
# Epoch 72/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1835 - accuracy: 0.9461
# Epoch 00072: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1835 - accuracy: 0.9461
# Epoch 73/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9449
# Epoch 00073: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1964 - accuracy: 0.9449
# Epoch 74/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.2003 - accuracy: 0.9452
# Epoch 00074: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2001 - accuracy: 0.9453
# Epoch 75/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1849 - accuracy: 0.9471
# Epoch 00075: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 18ms/step - loss: 0.1849 - accuracy: 0.9471
# Epoch 76/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1844 - accuracy: 0.9486
# Epoch 00076: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1844 - accuracy: 0.9486
# Epoch 77/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1798 - accuracy: 0.9501
# Epoch 00077: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1798 - accuracy: 0.9501
# Epoch 78/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1825 - accuracy: 0.9486
# Epoch 00078: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1825 - accuracy: 0.9486
# Epoch 79/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1859 - accuracy: 0.9488
# Epoch 00079: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1860 - accuracy: 0.9487
# Epoch 80/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1841 - accuracy: 0.9482
# Epoch 00080: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1840 - accuracy: 0.9482
# Epoch 81/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1807 - accuracy: 0.9503
# Epoch 00081: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1806 - accuracy: 0.9503
# Epoch 82/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1795 - accuracy: 0.9521 ETA: 0s - l
# Epoch 00082: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1799 - accuracy: 0.9520
# Epoch 83/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1716 - accuracy: 0.9504
# Epoch 00083: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1717 - accuracy: 0.9503
# Epoch 84/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1737 - accuracy: 0.9508
# Epoch 00084: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1738 - accuracy: 0.9508
# Epoch 85/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1803 - accuracy: 0.9510
# Epoch 00085: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1802 - accuracy: 0.9510
# Epoch 86/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1776 - accuracy: 0.9489
# Epoch 00086: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1777 - accuracy: 0.9488
# Epoch 87/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1700 - accuracy: 0.9530
# Epoch 00087: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1700 - accuracy: 0.9529
# Epoch 88/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1729 - accuracy: 0.9511
# Epoch 00088: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1729 - accuracy: 0.9511
# Epoch 89/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1705 - accuracy: 0.9519
# Epoch 00089: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1704 - accuracy: 0.9520
# Epoch 90/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9492 ETA: 0s - loss: 0.1822 - accura
# Epoch 00090: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1819 - accuracy: 0.9492
# Epoch 91/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1752 - accuracy: 0.9525
# Epoch 00091: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1750 - accuracy: 0.9525
# Epoch 92/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9529
# Epoch 00092: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1694 - accuracy: 0.9529
# Epoch 93/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1708 - accuracy: 0.9529
# Epoch 00093: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1708 - accuracy: 0.9529
# Epoch 94/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1674 - accuracy: 0.9536
# Epoch 00094: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1673 - accuracy: 0.9536
# Epoch 95/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1680 - accuracy: 0.9537 E
# Epoch 00095: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1679 - accuracy: 0.9537
# Epoch 96/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1660 - accuracy: 0.9530
# Epoch 00096: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1659 - accuracy: 0.9530
# Epoch 97/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1754 - accuracy: 0.9515
# Epoch 00097: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1755 - accuracy: 0.9515
# Epoch 98/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1639 - accuracy: 0.9532
# Epoch 00098: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1638 - accuracy: 0.9533
# Epoch 99/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1616 - accuracy: 0.9556
# Epoch 00099: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1616 - accuracy: 0.9556
# Epoch 100/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9564
# Epoch 00100: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1609 - accuracy: 0.9564
# Epoch 101/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1669 - accuracy: 0.9544
# Epoch 00101: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1669 - accuracy: 0.9544
# Epoch 102/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1781 - accuracy: 0.9540
# Epoch 00102: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1781 - accuracy: 0.9539
# Epoch 103/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1647 - accuracy: 0.9547
# Epoch 00103: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1646 - accuracy: 0.9548
# Epoch 104/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1642 - accuracy: 0.9544
# Epoch 00104: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1643 - accuracy: 0.9544
# Epoch 105/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1561 - accuracy: 0.9568
# Epoch 00105: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1559 - accuracy: 0.9568
# Epoch 106/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1612 - accuracy: 0.9557
# Epoch 00106: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1613 - accuracy: 0.9557
# Epoch 107/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1606 - accuracy: 0.9562
# Epoch 00107: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1605 - accuracy: 0.9562
# Epoch 108/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1706 - accuracy: 0.9555
# Epoch 00108: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1706 - accuracy: 0.9555
# Epoch 109/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1624 - accuracy: 0.9561
# Epoch 00109: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1624 - accuracy: 0.9560
# Epoch 110/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1761 - accuracy: 0.9534
# Epoch 00110: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1761 - accuracy: 0.9534
# Epoch 111/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1602 - accuracy: 0.9562 ETA: 0s - loss: 0.1602 - accuracy: 0.95
# Epoch 00111: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1606 - accuracy: 0.9561
# Epoch 112/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1629 - accuracy: 0.9567
# Epoch 00112: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1631 - accuracy: 0.9567
# Epoch 113/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1635 - accuracy: 0.9555
# Epoch 00113: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1636 - accuracy: 0.9555
# Epoch 114/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1639 - accuracy: 0.9556
# Epoch 00114: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1637 - accuracy: 0.9557
# Epoch 115/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1553 - accuracy: 0.9565
# Epoch 00115: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1552 - accuracy: 0.9565
# Epoch 116/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1622 - accuracy: 0.9555
# Epoch 00116: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1621 - accuracy: 0.9555
# Epoch 117/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1667 - accuracy: 0.9550
# Epoch 00117: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1671 - accuracy: 0.9548
# Epoch 118/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1583 - accuracy: 0.9569
# Epoch 00118: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1581 - accuracy: 0.9570
# Epoch 119/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1560 - accuracy: 0.9586
# Epoch 00119: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1560 - accuracy: 0.9586
# Epoch 120/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1608 - accuracy: 0.9579
# Epoch 00120: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 31s 17ms/step - loss: 0.1608 - accuracy: 0.9578
# Epoch 121/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1663 - accuracy: 0.9562
# Epoch 00121: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1663 - accuracy: 0.9562
# Epoch 122/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1658 - accuracy: 0.9565
# Epoch 00122: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1656 - accuracy: 0.9565
# Epoch 123/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1529 - accuracy: 0.9575
# Epoch 00123: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1532 - accuracy: 0.9575
# Epoch 124/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1507 - accuracy: 0.9586
# Epoch 00124: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1506 - accuracy: 0.9586
# Epoch 125/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1621 - accuracy: 0.9570
# Epoch 00125: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1620 - accuracy: 0.9570
# Epoch 126/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1532 - accuracy: 0.9583
# Epoch 00126: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1531 - accuracy: 0.9583
# Epoch 127/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1659 - accuracy: 0.9573
# Epoch 00127: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1661 - accuracy: 0.9573
# Epoch 128/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1592 - accuracy: 0.9585
# Epoch 00128: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1591 - accuracy: 0.9586
# Epoch 129/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1625 - accuracy: 0.9579
# Epoch 00129: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1624 - accuracy: 0.9579
# Epoch 130/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1490 - accuracy: 0.9596
# Epoch 00130: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1489 - accuracy: 0.9596
# Epoch 131/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9586
# Epoch 00131: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1567 - accuracy: 0.9586
# Epoch 132/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1571 - accuracy: 0.9584
# Epoch 00132: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1570 - accuracy: 0.9584
# Epoch 133/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1545 - accuracy: 0.9586
# Epoch 00133: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1546 - accuracy: 0.9586
# Epoch 134/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1512 - accuracy: 0.9587
# Epoch 00134: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1511 - accuracy: 0.9587
# Epoch 135/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1611 - accuracy: 0.9582
# Epoch 00135: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1611 - accuracy: 0.9582
# Epoch 136/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9595
# Epoch 00136: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1556 - accuracy: 0.9595
# Epoch 137/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1569 - accuracy: 0.9582
# Epoch 00137: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1568 - accuracy: 0.9582
# Epoch 138/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1533 - accuracy: 0.9591
# Epoch 00138: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1534 - accuracy: 0.9591
# Epoch 139/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1566 - accuracy: 0.9576
# Epoch 00139: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1566 - accuracy: 0.9576
# Epoch 140/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1501 - accuracy: 0.9606
# Epoch 00140: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1500 - accuracy: 0.9606
# Epoch 141/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1490 - accuracy: 0.9607 ETA: 0s - loss: 0
# Epoch 00141: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1490 - accuracy: 0.9607
# Epoch 142/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1573 - accuracy: 0.9597
# Epoch 00142: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1575 - accuracy: 0.9596
# Epoch 143/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1563 - accuracy: 0.9584
# Epoch 00143: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1563 - accuracy: 0.9584
# Epoch 144/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1497 - accuracy: 0.9609
# Epoch 00144: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1497 - accuracy: 0.9609
# Epoch 145/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1499 - accuracy: 0.9606
# Epoch 00145: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1506 - accuracy: 0.9605
# Epoch 146/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1587 - accuracy: 0.9585
# Epoch 00146: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1588 - accuracy: 0.9584
# Epoch 147/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1468 - accuracy: 0.9596
# Epoch 00147: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1469 - accuracy: 0.9596
# Epoch 148/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1529 - accuracy: 0.9592
# Epoch 00148: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1530 - accuracy: 0.9591
# Epoch 149/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.2813 - accuracy: 0.9597
# Epoch 00149: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.2813 - accuracy: 0.9597
# Epoch 150/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1389 - accuracy: 0.9620
# Epoch 00150: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1389 - accuracy: 0.9620
# Epoch 151/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1767 - accuracy: 0.9641
# Epoch 00151: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1767 - accuracy: 0.9641
# Epoch 152/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1371 - accuracy: 0.9638
# Epoch 00152: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1369 - accuracy: 0.9638
# Epoch 153/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1322 - accuracy: 0.9639
# Epoch 00153: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1321 - accuracy: 0.9639
# Epoch 154/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1339 - accuracy: 0.9639
# Epoch 00154: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1340 - accuracy: 0.9640
# Epoch 155/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1251 - accuracy: 0.9658
# Epoch 00155: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1250 - accuracy: 0.9659
# Epoch 156/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1366 - accuracy: 0.9646
# Epoch 00156: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1365 - accuracy: 0.9646
# Epoch 157/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1270 - accuracy: 0.9653
# Epoch 00157: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1269 - accuracy: 0.9654
# Epoch 158/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1171 - accuracy: 0.9675
# Epoch 00158: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1171 - accuracy: 0.9675
# Epoch 159/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1205 - accuracy: 0.9664
# Epoch 00159: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1205 - accuracy: 0.9664
# Epoch 160/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1250 - accuracy: 0.9656
# Epoch 00160: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1250 - accuracy: 0.9656
# Epoch 161/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9659
# Epoch 00161: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1206 - accuracy: 0.9659
# Epoch 162/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9673
# Epoch 00162: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1152 - accuracy: 0.9673
# Epoch 163/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1157 - accuracy: 0.9673
# Epoch 00163: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1156 - accuracy: 0.9673
# Epoch 164/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1252 - accuracy: 0.9666
# Epoch 00164: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1253 - accuracy: 0.9666
# Epoch 165/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1222 - accuracy: 0.9678
# Epoch 00165: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1221 - accuracy: 0.9678
# Epoch 166/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9669
# Epoch 00166: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1220 - accuracy: 0.9669
# Epoch 167/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1163 - accuracy: 0.9673
# Epoch 00167: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1164 - accuracy: 0.9673
# Epoch 168/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9669 ETA: 0s - loss: 0.1181 - accu
# Epoch 00168: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1179 - accuracy: 0.9669
# Epoch 169/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1238 - accuracy: 0.9671
# Epoch 00169: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1237 - accuracy: 0.9671
# Epoch 170/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1211 - accuracy: 0.9678
# Epoch 00170: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1212 - accuracy: 0.9678
# Epoch 171/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9689
# Epoch 00171: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1150 - accuracy: 0.9689
# Epoch 172/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9678
# Epoch 00172: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1185 - accuracy: 0.9678
# Epoch 173/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1238 - accuracy: 0.9670
# Epoch 00173: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1240 - accuracy: 0.9669
# Epoch 174/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1170 - accuracy: 0.9683
# Epoch 00174: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1171 - accuracy: 0.9682
# Epoch 175/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1187 - accuracy: 0.9687
# Epoch 00175: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1187 - accuracy: 0.9687
# Epoch 176/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1188 - accuracy: 0.9683
# Epoch 00176: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1188 - accuracy: 0.9682
# Epoch 177/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9682
# Epoch 00177: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1168 - accuracy: 0.9682
# Epoch 178/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1187 - accuracy: 0.9684
# Epoch 00178: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1185 - accuracy: 0.9685
# Epoch 179/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1211 - accuracy: 0.9681
# Epoch 00179: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1210 - accuracy: 0.9681
# Epoch 180/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9690
# Epoch 00180: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1133 - accuracy: 0.9690
# Epoch 181/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1189 - accuracy: 0.9681
# Epoch 00181: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1190 - accuracy: 0.9680
# Epoch 182/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9686
# Epoch 00182: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1177 - accuracy: 0.9686
# Epoch 183/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1282 - accuracy: 0.9659
# Epoch 00183: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1281 - accuracy: 0.9660
# Epoch 184/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1321 - accuracy: 0.9665
# Epoch 00184: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1322 - accuracy: 0.9665
# Epoch 185/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1539 - accuracy: 0.9628
# Epoch 00185: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1538 - accuracy: 0.9628
# Epoch 186/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1526 - accuracy: 0.9633
# Epoch 00186: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1524 - accuracy: 0.9633
# Epoch 187/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1713 - accuracy: 0.9577
# Epoch 00187: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1716 - accuracy: 0.9577
# Epoch 188/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1579 - accuracy: 0.9602
# Epoch 00188: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1578 - accuracy: 0.9601
# Epoch 189/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9592
# Epoch 00189: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1633 - accuracy: 0.9592
# Epoch 190/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1659 - accuracy: 0.9588
# Epoch 00190: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1658 - accuracy: 0.9588
# Epoch 191/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1824 - accuracy: 0.9575
# Epoch 00191: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1828 - accuracy: 0.9575
# Epoch 192/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1617 - accuracy: 0.9606
# Epoch 00192: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1616 - accuracy: 0.9606
# Epoch 193/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1635 - accuracy: 0.9602
# Epoch 00193: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1635 - accuracy: 0.9602
# Epoch 194/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1653 - accuracy: 0.9592
# Epoch 00194: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1654 - accuracy: 0.9591
# Epoch 195/200
# 1750/1752 [============================>.] - ETA: 0s - loss: 0.1605 - accuracy: 0.9600
# Epoch 00195: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1604 - accuracy: 0.9600
# Epoch 196/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1719 - accuracy: 0.9578
# Epoch 00196: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1721 - accuracy: 0.9578
# Epoch 197/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1812 - accuracy: 0.9570
# Epoch 00197: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1811 - accuracy: 0.9570
# Epoch 198/200
# 1751/1752 [============================>.] - ETA: 0s - loss: 0.1680 - accuracy: 0.9588
# Epoch 00198: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1680 - accuracy: 0.9588
# Epoch 199/200
# 1752/1752 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9584
# Epoch 00199: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 30s 17ms/step - loss: 0.1746 - accuracy: 0.9584
# Epoch 200/200
# 1749/1752 [============================>.] - ETA: 0s - loss: 0.1662 - accuracy: 0.9573
# Epoch 00200: saving model to D:\Desktop\code\BrainBeats\Symphony\src\models\FunkDrums/checkpoints\cp.ckpt
# 1752/1752 [==============================] - 29s 17ms/step - loss: 0.1660 - accuracy: 0.9573
